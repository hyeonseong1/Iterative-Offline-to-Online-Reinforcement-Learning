# %%
from rollout_by_pid import rollout
import pandas as pd

# %%
TOTAL_TIMESTEPS = 10_000
GOAL_RANGE = 0.3
SPEED = 1.5

# %%
dict_logs = rollout(total_timesteps=TOTAL_TIMESTEPS, goal_range=GOAL_RANGE, speed=SPEED)
# Out:
# argv[0]=--background_color_red=0.8745098114013672
# argv[1]=--background_color_green=0.21176470816135406
# argv[2]=--background_color_blue=0.1764705926179886
# /home/hs/anaconda3/envs/o2o/lib/python3.8/site-packages/gymnasium/core.py:311: UserWarning: WARN: env.task to get variables from other wrappers is deprecated and will be removed in v1.0, to get this variable you can do `env.unwrapped.task` for environment variables or `env.get_wrapper_attr('task')` that will search the reminding wrappers.
#   logger.warn(
# -16.985611510791365
# 17.985611510791365
# 556
# 10000

# %%
data_df = pd.DataFrame(dict_logs)
data_df
# Out:
#            s_x           s_y       s_z     s_v_x     s_v_y     s_v_z  \
# 0     0.038440 -2.194472e-12  0.197400  0.000000 -0.000000  0.000000
# 1     0.036803  8.199004e-03  0.195996 -0.013622  0.090759 -0.010980
# 2     0.035208  1.614794e-02  0.194672 -0.012965  0.071909 -0.010161
# 3     0.033659  2.358268e-02  0.193427 -0.012678  0.067907 -0.009559
# 4     0.032160  3.056594e-02  0.192257 -0.012296  0.062612 -0.008989
# ...        ...           ...       ...       ...       ...       ...
# 9995 -0.007191 -7.038090e-03  0.169526 -0.023449 -0.002971 -0.013002
# 9996 -0.010023 -7.406784e-03  0.167996 -0.022283 -0.002776 -0.012146
# 9997 -0.012724 -7.751090e-03  0.166558 -0.021157 -0.002593 -0.011338
# 9998 -0.015297 -8.072576e-03  0.165207 -0.020070 -0.002423 -0.010575
# 9999  0.038440 -2.194472e-12  0.197400  0.000000 -0.000000  0.000000
#
#          s_g_x     s_g_y     s_g_z       a_x       a_y       a_z
# 0     0.003220  0.132761  0.174561 -0.052830  0.199141 -0.034259
# ...

# %%
data_df.to_csv(f"cache/reach_toal_{TOTAL_TIMESTEPS}_range_{GOAL_RANGE:.1f}_speed_{SPEED:.1f}.csv", index=False)

# %%
tmp = pd.read_csv(f"cache/reach_toal_{TOTAL_TIMESTEPS}_range_{GOAL_RANGE:.1f}_speed_{SPEED:.1f}.csv")
tmp
# Out:
#            s_x           s_y       s_z     s_v_x     s_v_y     s_v_z  \
# 0     0.038440 -2.194472e-12  0.197400  0.000000 -0.000000  0.000000
# 1     0.036803  8.199004e-03  0.195996 -0.013622  0.090759 -0.010980
# 2     0.035208  1.614794e-02  0.194672 -0.012965  0.071909 -0.010161
# 3     0.033659  2.358268e-02  0.193427 -0.012678  0.067907 -0.009559
# 4     0.032160  3.056594e-02  0.192257 -0.012296  0.062612 -0.008989
# ...        ...           ...       ...       ...       ...       ...
# 9995 -0.007191 -7.038090e-03  0.169526 -0.023449 -0.002971 -0.013002
# 9996 -0.010023 -7.406784e-03  0.167996 -0.022283 -0.002776 -0.012146
# 9997 -0.012724 -7.751089e-03  0.166558 -0.021157 -0.002593 -0.011338
# 9998 -0.015297 -8.072576e-03  0.165207 -0.020070 -0.002423 -0.010575
# 9999  0.038440 -2.194472e-12  0.197400  0.000000 -0.000000  0.000000
#
#          s_g_x     s_g_y     s_g_z       a_x       a_y       a_z
# 0     0.003220  0.132761  0.174561 -0.052830  0.199141 -0.034259
# ...

# %%
import sys
from pathlib import Path
import gym
import d4rl

PROJECT_ROOT_DIR = Path().absolute().parent
PROJECT_ROOT_DIR

if str(PROJECT_ROOT_DIR.absolute()) not in sys.path:
    sys.path.append(str(PROJECT_ROOT_DIR.absolute()))

from models.sb3_model import PPOWithBCLoss
from utils.sb3_env_wrappers import ScaledObservationWrapper
from rollout import rollout, save_data_to_h5_file
from utils.load_data import load_data, scale_obs, split_data

# %%
RL_EXPERIMENT_NAME = "iter_1/medium_halfcheetah_1e7steps_8envs_kl0_loss_1"
ENV_NAME = "halfcheetah-medium-v2"

# %%
origin_env = gym.make(ENV_NAME)
    
obs, acts, infos = load_data(origin_env)
scaled_obs, scaler = scale_obs(obs)

env = ScaledObservationWrapper(env=origin_env, scaler=scaler)
# Out:
# /home/ucav/anaconda3/envs/d4rl0/lib/python3.8/site-packages/gym/spaces/box.py:73: UserWarning: WARN: Box bound precision lowered by casting to float32
#   logger.warn(
# load datafile: 100%|██████████| 21/21 [00:01<00:00, 14.49it/s]

# %%
policy_save_dir = PROJECT_ROOT_DIR / "checkpoints" / "rl" / RL_EXPERIMENT_NAME
algo_ppo = PPOWithBCLoss.load(str((policy_save_dir / "best_model").absolute()))
algo_ppo.policy.set_training_mode(False)

# %%
dataset = rollout(algo_ppo.policy, env, max_path=1000, num_data=1_000_000)
# Out:
# Finished trajectory. Len=1000, Returns=9000.263126. Progress:0/1000000
# Finished trajectory. Len=1000, Returns=8458.259447. Progress:1000/1000000
# Finished trajectory. Len=1000, Returns=8827.138391. Progress:2000/1000000
# Finished trajectory. Len=1000, Returns=8942.044120. Progress:3000/1000000
# Finished trajectory. Len=1000, Returns=9046.498397. Progress:4000/1000000
# Finished trajectory. Len=1000, Returns=9010.542340. Progress:5000/1000000
# Finished trajectory. Len=1000, Returns=8672.112090. Progress:6000/1000000
# Finished trajectory. Len=1000, Returns=7164.153805. Progress:7000/1000000
# Finished trajectory. Len=1000, Returns=8322.914237. Progress:8000/1000000
# Finished trajectory. Len=1000, Returns=8444.417726. Progress:9000/1000000
# Finished trajectory. Len=1000, Returns=8823.248023. Progress:10000/1000000
# Finished trajectory. Len=1000, Returns=8593.086274. Progress:11000/1000000
# Finished trajectory. Len=1000, Returns=8750.062422. Progress:12000/1000000
# Finished trajectory. Len=1000, Returns=8315.570470. Progress:13000/1000000
# Finished trajectory. Len=1000, Returns=8295.768324. Progress:14000/1000000
# Finished trajectory. Len=1000, Returns=8714.127375. Progress:15000/1000000
# Finished trajectory. Len=1000, Returns=8755.076869. Progress:16000/1000000
# Finished trajectory. Len=1000, Returns=8599.073798. Progress:17000/1000000
# Finished trajectory. Len=1000, Returns=8758.850604. Progress:18000/1000000
# Finished trajectory. Len=1000, Returns=9072.481816. Progress:19000/1000000
# Finished trajectory. Len=1000, Returns=8686.075017. Progress:20000/1000000
# Finished trajectory. Len=1000, Returns=9118.631053. Progress:21000/1000000
# Finished trajectory. Len=1000, Returns=8752.502315. Progress:22000/1000000
# Finished trajectory. Len=1000, Returns=8371.764203. Progress:23000/1000000
# Finished trajectory. Len=1000, Returns=8759.479892. Progress:24000/1000000
# Finished trajectory. Len=1000, Returns=8958.860329. Progress:25000/1000000
# Finished trajectory. Len=1000, Returns=8720.276930. Progress:26000/1000000
# Finished trajectory. Len=1000, Returns=8763.696867. Progress:27000/1000000
# Finished trajectory. Len=1000, Returns=8785.188123. Progress:28000/1000000
# Finished trajectory. Len=1000, Returns=8733.417134. Progress:29000/1000000
# Finished trajectory. Len=1000, Returns=8676.639241. Progress:30000/1000000
# Finished trajectory. Len=1000, Returns=8900.616091. Progress:31000/1000000
# Finished trajectory. Len=1000, Returns=8817.674884. Progress:32000/1000000
# Finished trajectory. Len=1000, Returns=8582.083826. Progress:33000/1000000
# Finished trajectory. Len=1000, Returns=8672.404748. Progress:34000/1000000
# Finished trajectory. Len=1000, Returns=7481.895332. Progress:35000/1000000
# Finished trajectory. Len=1000, Returns=8589.044914. Progress:36000/1000000
# Finished trajectory. Len=1000, Returns=8574.245509. Progress:37000/1000000
# Finished trajectory. Len=1000, Returns=8924.168355. Progress:38000/1000000
# Finished trajectory. Len=1000, Returns=8547.848320. Progress:39000/1000000
# Finished trajectory. Len=1000, Returns=8445.217631. Progress:40000/1000000
# Finished trajectory. Len=1000, Returns=8423.760472. Progress:41000/1000000
# Finished trajectory. Len=1000, Returns=8465.150642. Progress:42000/1000000
# Finished trajectory. Len=1000, Returns=9151.349316. Progress:43000/1000000
# Finished trajectory. Len=1000, Returns=8804.066800. Progress:44000/1000000
# Finished trajectory. Len=1000, Returns=8512.978512. Progress:45000/1000000
# Finished trajectory. Len=1000, Returns=8664.957452. Progress:46000/1000000
# Finished trajectory. Len=1000, Returns=8890.413527. Progress:47000/1000000
# Finished trajectory. Len=1000, Returns=8944.173059. Progress:48000/1000000
# Finished trajectory. Len=1000, Returns=5063.209265. Progress:49000/1000000
# Finished trajectory. Len=1000, Returns=8069.885215. Progress:50000/1000000
# Finished trajectory. Len=1000, Returns=8725.500523. Progress:51000/1000000
# Finished trajectory. Len=1000, Returns=8824.833806. Progress:52000/1000000
# Finished trajectory. Len=1000, Returns=8927.259672. Progress:53000/1000000
# Finished trajectory. Len=1000, Returns=9014.601727. Progress:54000/1000000
# Finished trajectory. Len=1000, Returns=8876.775156. Progress:55000/1000000
# Finished trajectory. Len=1000, Returns=9039.062492. Progress:56000/1000000
# Finished trajectory. Len=1000, Returns=7542.081939. Progress:57000/1000000
# Finished trajectory. Len=1000, Returns=8657.278177. Progress:58000/1000000
# Finished trajectory. Len=1000, Returns=8787.596034. Progress:59000/1000000
# Finished trajectory. Len=1000, Returns=7534.940924. Progress:60000/1000000
# Finished trajectory. Len=1000, Returns=8446.851944. Progress:61000/1000000
# Finished trajectory. Len=1000, Returns=8897.017619. Progress:62000/1000000
# Finished trajectory. Len=1000, Returns=7071.532566. Progress:63000/1000000
# Finished trajectory. Len=1000, Returns=8417.414284. Progress:64000/1000000
# Finished trajectory. Len=1000, Returns=6429.664948. Progress:65000/1000000
# Finished trajectory. Len=1000, Returns=8516.527401. Progress:66000/1000000
# Finished trajectory. Len=1000, Returns=8701.090732. Progress:67000/1000000
# Finished trajectory. Len=1000, Returns=8855.346271. Progress:68000/1000000
# Finished trajectory. Len=1000, Returns=8461.015626. Progress:69000/1000000
# Finished trajectory. Len=1000, Returns=8617.610301. Progress:70000/1000000
# Finished trajectory. Len=1000, Returns=8813.340106. Progress:71000/1000000
# Finished trajectory. Len=1000, Returns=4024.232699. Progress:72000/1000000
# Finished trajectory. Len=1000, Returns=8564.507233. Progress:73000/1000000
# Finished trajectory. Len=1000, Returns=8160.900824. Progress:74000/1000000
# Finished trajectory. Len=1000, Returns=8717.715747. Progress:75000/1000000
# Finished trajectory. Len=1000, Returns=8824.871356. Progress:76000/1000000
# Finished trajectory. Len=1000, Returns=8817.255441. Progress:77000/1000000
# Finished trajectory. Len=1000, Returns=8660.819854. Progress:78000/1000000
# Finished trajectory. Len=1000, Returns=8230.913811. Progress:79000/1000000
# Finished trajectory. Len=1000, Returns=8092.548122. Progress:80000/1000000
# Finished trajectory. Len=1000, Returns=8978.066697. Progress:81000/1000000
# Finished trajectory. Len=1000, Returns=8609.380454. Progress:82000/1000000
# Finished trajectory. Len=1000, Returns=8884.479417. Progress:83000/1000000
# Finished trajectory. Len=1000, Returns=8748.228007. Progress:84000/1000000
# Finished trajectory. Len=1000, Returns=8722.284876. Progress:85000/1000000
# Finished trajectory. Len=1000, Returns=9059.208421. Progress:86000/1000000
# Finished trajectory. Len=1000, Returns=8661.280711. Progress:87000/1000000
# Finished trajectory. Len=1000, Returns=7983.380825. Progress:88000/1000000
# Finished trajectory. Len=1000, Returns=8571.538937. Progress:89000/1000000
# Finished trajectory. Len=1000, Returns=8818.379461. Progress:90000/1000000
# Finished trajectory. Len=1000, Returns=8269.268858. Progress:91000/1000000
# Finished trajectory. Len=1000, Returns=9016.059161. Progress:92000/1000000
# Finished trajectory. Len=1000, Returns=8815.168094. Progress:93000/1000000
# Finished trajectory. Len=1000, Returns=8471.308977. Progress:94000/1000000
# Finished trajectory. Len=1000, Returns=8690.448865. Progress:95000/1000000
# Finished trajectory. Len=1000, Returns=8578.483479. Progress:96000/1000000
# Finished trajectory. Len=1000, Returns=8962.410297. Progress:97000/1000000
# Finished trajectory. Len=1000, Returns=8847.253440. Progress:98000/1000000
# Finished trajectory. Len=1000, Returns=8937.690749. Progress:99000/1000000
# Finished trajectory. Len=1000, Returns=8285.348403. Progress:100000/1000000
# Finished trajectory. Len=1000, Returns=8159.879753. Progress:101000/1000000
# Finished trajectory. Len=1000, Returns=8509.280815. Progress:102000/1000000
# Finished trajectory. Len=1000, Returns=8837.030817. Progress:103000/1000000
# Finished trajectory. Len=1000, Returns=8741.180981. Progress:104000/1000000
# Finished trajectory. Len=1000, Returns=8205.136567. Progress:105000/1000000
# Finished trajectory. Len=1000, Returns=8973.156001. Progress:106000/1000000
# Finished trajectory. Len=1000, Returns=8842.364124. Progress:107000/1000000
# Finished trajectory. Len=1000, Returns=8889.754550. Progress:108000/1000000
# Finished trajectory. Len=1000, Returns=7767.679597. Progress:109000/1000000
# Finished trajectory. Len=1000, Returns=8980.233713. Progress:110000/1000000
# Finished trajectory. Len=1000, Returns=8686.630997. Progress:111000/1000000
# Finished trajectory. Len=1000, Returns=8503.656015. Progress:112000/1000000
# Finished trajectory. Len=1000, Returns=8680.610988. Progress:113000/1000000
# Finished trajectory. Len=1000, Returns=8809.966210. Progress:114000/1000000
# Finished trajectory. Len=1000, Returns=8927.122585. Progress:115000/1000000
# Finished trajectory. Len=1000, Returns=8682.173734. Progress:116000/1000000
# Finished trajectory. Len=1000, Returns=8399.525364. Progress:117000/1000000
# Finished trajectory. Len=1000, Returns=8923.717049. Progress:118000/1000000
# Finished trajectory. Len=1000, Returns=7993.259439. Progress:119000/1000000
# Finished trajectory. Len=1000, Returns=8749.793456. Progress:120000/1000000
# Finished trajectory. Len=1000, Returns=8623.891240. Progress:121000/1000000
# Finished trajectory. Len=1000, Returns=8764.624706. Progress:122000/1000000
# Finished trajectory. Len=1000, Returns=8612.654139. Progress:123000/1000000
# Finished trajectory. Len=1000, Returns=8777.505841. Progress:124000/1000000
# Finished trajectory. Len=1000, Returns=8618.359496. Progress:125000/1000000
# Finished trajectory. Len=1000, Returns=8922.447627. Progress:126000/1000000
# Finished trajectory. Len=1000, Returns=8895.689838. Progress:127000/1000000
# Finished trajectory. Len=1000, Returns=8522.101867. Progress:128000/1000000
# Finished trajectory. Len=1000, Returns=8773.693677. Progress:129000/1000000
# Finished trajectory. Len=1000, Returns=9010.037467. Progress:130000/1000000
# Finished trajectory. Len=1000, Returns=8345.725393. Progress:131000/1000000
# Finished trajectory. Len=1000, Returns=8757.236607. Progress:132000/1000000
# Finished trajectory. Len=1000, Returns=8749.697116. Progress:133000/1000000
# Finished trajectory. Len=1000, Returns=8847.524789. Progress:134000/1000000
# Finished trajectory. Len=1000, Returns=8999.934678. Progress:135000/1000000
# Finished trajectory. Len=1000, Returns=8871.869193. Progress:136000/1000000
# Finished trajectory. Len=1000, Returns=8704.420446. Progress:137000/1000000
# Finished trajectory. Len=1000, Returns=8645.903438. Progress:138000/1000000
# Finished trajectory. Len=1000, Returns=8367.371414. Progress:139000/1000000
# Finished trajectory. Len=1000, Returns=8327.903764. Progress:140000/1000000
# Finished trajectory. Len=1000, Returns=8896.382076. Progress:141000/1000000
# Finished trajectory. Len=1000, Returns=8394.688552. Progress:142000/1000000
# Finished trajectory. Len=1000, Returns=8702.190959. Progress:143000/1000000
# Finished trajectory. Len=1000, Returns=8453.586935. Progress:144000/1000000
# Finished trajectory. Len=1000, Returns=6058.543706. Progress:145000/1000000
# Finished trajectory. Len=1000, Returns=8430.873328. Progress:146000/1000000
# Finished trajectory. Len=1000, Returns=8740.493305. Progress:147000/1000000
# Finished trajectory. Len=1000, Returns=8565.887403. Progress:148000/1000000
# Finished trajectory. Len=1000, Returns=8722.071882. Progress:149000/1000000
# Finished trajectory. Len=1000, Returns=8719.775631. Progress:150000/1000000
# Finished trajectory. Len=1000, Returns=8553.627939. Progress:151000/1000000
# Finished trajectory. Len=1000, Returns=8379.924484. Progress:152000/1000000
# Finished trajectory. Len=1000, Returns=8798.449264. Progress:153000/1000000
# Finished trajectory. Len=1000, Returns=8657.778576. Progress:154000/1000000
# Finished trajectory. Len=1000, Returns=8684.153206. Progress:155000/1000000
# Finished trajectory. Len=1000, Returns=8433.841969. Progress:156000/1000000
# Finished trajectory. Len=1000, Returns=7443.893167. Progress:157000/1000000
# Finished trajectory. Len=1000, Returns=8902.663323. Progress:158000/1000000
# Finished trajectory. Len=1000, Returns=7901.894661. Progress:159000/1000000
# Finished trajectory. Len=1000, Returns=8609.209927. Progress:160000/1000000
# Finished trajectory. Len=1000, Returns=8929.827236. Progress:161000/1000000
# Finished trajectory. Len=1000, Returns=8486.793461. Progress:162000/1000000
# Finished trajectory. Len=1000, Returns=9043.812727. Progress:163000/1000000
# Finished trajectory. Len=1000, Returns=8839.781537. Progress:164000/1000000
# Finished trajectory. Len=1000, Returns=8729.469391. Progress:165000/1000000
# Finished trajectory. Len=1000, Returns=8491.086871. Progress:166000/1000000
# Finished trajectory. Len=1000, Returns=8911.367147. Progress:167000/1000000
# Finished trajectory. Len=1000, Returns=8438.278437. Progress:168000/1000000
# Finished trajectory. Len=1000, Returns=9075.541066. Progress:169000/1000000
# Finished trajectory. Len=1000, Returns=8426.900150. Progress:170000/1000000
# Finished trajectory. Len=1000, Returns=8640.314304. Progress:171000/1000000
# Finished trajectory. Len=1000, Returns=8234.672093. Progress:172000/1000000
# Finished trajectory. Len=1000, Returns=8728.085991. Progress:173000/1000000
# Finished trajectory. Len=1000, Returns=8285.494607. Progress:174000/1000000
# Finished trajectory. Len=1000, Returns=8862.839715. Progress:175000/1000000
# Finished trajectory. Len=1000, Returns=8799.046362. Progress:176000/1000000
# Finished trajectory. Len=1000, Returns=8731.980540. Progress:177000/1000000
# Finished trajectory. Len=1000, Returns=9033.257925. Progress:178000/1000000
# Finished trajectory. Len=1000, Returns=8555.874734. Progress:179000/1000000
# Finished trajectory. Len=1000, Returns=8587.718246. Progress:180000/1000000
# Finished trajectory. Len=1000, Returns=9095.590626. Progress:181000/1000000
# Finished trajectory. Len=1000, Returns=8629.426780. Progress:182000/1000000
# Finished trajectory. Len=1000, Returns=8516.461497. Progress:183000/1000000
# Finished trajectory. Len=1000, Returns=8363.669459. Progress:184000/1000000
# Finished trajectory. Len=1000, Returns=8924.641988. Progress:185000/1000000
# Finished trajectory. Len=1000, Returns=8749.411570. Progress:186000/1000000
# Finished trajectory. Len=1000, Returns=8756.857799. Progress:187000/1000000
# Finished trajectory. Len=1000, Returns=8562.607714. Progress:188000/1000000
# Finished trajectory. Len=1000, Returns=9039.402838. Progress:189000/1000000
# Finished trajectory. Len=1000, Returns=8201.021769. Progress:190000/1000000
# Finished trajectory. Len=1000, Returns=8586.866717. Progress:191000/1000000
# Finished trajectory. Len=1000, Returns=8627.407380. Progress:192000/1000000
# Finished trajectory. Len=1000, Returns=8801.284113. Progress:193000/1000000
# Finished trajectory. Len=1000, Returns=8924.300693. Progress:194000/1000000
# Finished trajectory. Len=1000, Returns=8827.885093. Progress:195000/1000000
# Finished trajectory. Len=1000, Returns=5405.693124. Progress:196000/1000000
# Finished trajectory. Len=1000, Returns=8471.354989. Progress:197000/1000000
# Finished trajectory. Len=1000, Returns=8782.642024. Progress:198000/1000000
# Finished trajectory. Len=1000, Returns=8714.260911. Progress:199000/1000000
# Finished trajectory. Len=1000, Returns=8903.348014. Progress:200000/1000000
# Finished trajectory. Len=1000, Returns=8451.573603. Progress:201000/1000000
# Finished trajectory. Len=1000, Returns=8725.883551. Progress:202000/1000000
# Finished trajectory. Len=1000, Returns=8674.746352. Progress:203000/1000000
# Finished trajectory. Len=1000, Returns=8352.961006. Progress:204000/1000000
# Finished trajectory. Len=1000, Returns=9051.691221. Progress:205000/1000000
# Finished trajectory. Len=1000, Returns=8492.454601. Progress:206000/1000000
# Finished trajectory. Len=1000, Returns=7829.939076. Progress:207000/1000000
# Finished trajectory. Len=1000, Returns=8504.011815. Progress:208000/1000000
# Finished trajectory. Len=1000, Returns=8716.091864. Progress:209000/1000000
# Finished trajectory. Len=1000, Returns=8521.150196. Progress:210000/1000000
# Finished trajectory. Len=1000, Returns=8868.344739. Progress:211000/1000000
# Finished trajectory. Len=1000, Returns=8533.859046. Progress:212000/1000000
# Finished trajectory. Len=1000, Returns=8420.640744. Progress:213000/1000000
# Finished trajectory. Len=1000, Returns=8768.064598. Progress:214000/1000000
# Finished trajectory. Len=1000, Returns=8659.556692. Progress:215000/1000000
# Finished trajectory. Len=1000, Returns=8623.704886. Progress:216000/1000000
# Finished trajectory. Len=1000, Returns=8513.475002. Progress:217000/1000000
# Finished trajectory. Len=1000, Returns=8715.681383. Progress:218000/1000000
# Finished trajectory. Len=1000, Returns=8762.239137. Progress:219000/1000000
# Finished trajectory. Len=1000, Returns=8384.343255. Progress:220000/1000000
# Finished trajectory. Len=1000, Returns=8687.733879. Progress:221000/1000000
# Finished trajectory. Len=1000, Returns=8513.012610. Progress:222000/1000000
# Finished trajectory. Len=1000, Returns=8497.333314. Progress:223000/1000000
# Finished trajectory. Len=1000, Returns=8902.399059. Progress:224000/1000000
# Finished trajectory. Len=1000, Returns=7944.033235. Progress:225000/1000000
# Finished trajectory. Len=1000, Returns=8768.398747. Progress:226000/1000000
# Finished trajectory. Len=1000, Returns=9073.318119. Progress:227000/1000000
# Finished trajectory. Len=1000, Returns=8426.086049. Progress:228000/1000000
# Finished trajectory. Len=1000, Returns=8995.258121. Progress:229000/1000000
# Finished trajectory. Len=1000, Returns=8598.570022. Progress:230000/1000000
# Finished trajectory. Len=1000, Returns=8905.526121. Progress:231000/1000000
# Finished trajectory. Len=1000, Returns=8972.665951. Progress:232000/1000000
# Finished trajectory. Len=1000, Returns=8562.753190. Progress:233000/1000000
# Finished trajectory. Len=1000, Returns=8649.155710. Progress:234000/1000000
# Finished trajectory. Len=1000, Returns=8903.897925. Progress:235000/1000000
# Finished trajectory. Len=1000, Returns=8747.499358. Progress:236000/1000000
# Finished trajectory. Len=1000, Returns=8384.325803. Progress:237000/1000000
# Finished trajectory. Len=1000, Returns=8448.512329. Progress:238000/1000000
# Finished trajectory. Len=1000, Returns=8904.226624. Progress:239000/1000000
# Finished trajectory. Len=1000, Returns=8726.548706. Progress:240000/1000000
# Finished trajectory. Len=1000, Returns=8644.414233. Progress:241000/1000000
# Finished trajectory. Len=1000, Returns=8833.984732. Progress:242000/1000000
# Finished trajectory. Len=1000, Returns=8593.996528. Progress:243000/1000000
# Finished trajectory. Len=1000, Returns=7890.170038. Progress:244000/1000000
# Finished trajectory. Len=1000, Returns=8656.531500. Progress:245000/1000000
# Finished trajectory. Len=1000, Returns=8810.626199. Progress:246000/1000000
# Finished trajectory. Len=1000, Returns=4166.379554. Progress:247000/1000000
# Finished trajectory. Len=1000, Returns=8627.744362. Progress:248000/1000000
# Finished trajectory. Len=1000, Returns=9027.206542. Progress:249000/1000000
# Finished trajectory. Len=1000, Returns=8841.433608. Progress:250000/1000000
# Finished trajectory. Len=1000, Returns=8975.240503. Progress:251000/1000000
# Finished trajectory. Len=1000, Returns=8498.182328. Progress:252000/1000000
# Finished trajectory. Len=1000, Returns=8227.576854. Progress:253000/1000000
# Finished trajectory. Len=1000, Returns=8833.142365. Progress:254000/1000000
# Finished trajectory. Len=1000, Returns=8515.082278. Progress:255000/1000000
# Finished trajectory. Len=1000, Returns=8676.073134. Progress:256000/1000000
# Finished trajectory. Len=1000, Returns=8400.664020. Progress:257000/1000000
# Finished trajectory. Len=1000, Returns=8263.705951. Progress:258000/1000000
# Finished trajectory. Len=1000, Returns=8678.034069. Progress:259000/1000000
# Finished trajectory. Len=1000, Returns=8745.594727. Progress:260000/1000000
# Finished trajectory. Len=1000, Returns=8810.797743. Progress:261000/1000000
# Finished trajectory. Len=1000, Returns=8601.702629. Progress:262000/1000000
# Finished trajectory. Len=1000, Returns=9074.323131. Progress:263000/1000000
# Finished trajectory. Len=1000, Returns=8622.367130. Progress:264000/1000000
# Finished trajectory. Len=1000, Returns=8357.069114. Progress:265000/1000000
# Finished trajectory. Len=1000, Returns=8068.548813. Progress:266000/1000000
# Finished trajectory. Len=1000, Returns=8944.016232. Progress:267000/1000000
# Finished trajectory. Len=1000, Returns=8702.595809. Progress:268000/1000000
# Finished trajectory. Len=1000, Returns=8593.288804. Progress:269000/1000000
# Finished trajectory. Len=1000, Returns=8423.986272. Progress:270000/1000000
# Finished trajectory. Len=1000, Returns=8507.421032. Progress:271000/1000000
# Finished trajectory. Len=1000, Returns=8689.154334. Progress:272000/1000000
# Finished trajectory. Len=1000, Returns=9091.926780. Progress:273000/1000000
# Finished trajectory. Len=1000, Returns=8740.695825. Progress:274000/1000000
# Finished trajectory. Len=1000, Returns=8098.787139. Progress:275000/1000000
# Finished trajectory. Len=1000, Returns=9119.880559. Progress:276000/1000000
# Finished trajectory. Len=1000, Returns=8819.707272. Progress:277000/1000000
# Finished trajectory. Len=1000, Returns=8610.871197. Progress:278000/1000000
# Finished trajectory. Len=1000, Returns=8848.794194. Progress:279000/1000000
# Finished trajectory. Len=1000, Returns=7939.522547. Progress:280000/1000000
# Finished trajectory. Len=1000, Returns=8071.927890. Progress:281000/1000000
# Finished trajectory. Len=1000, Returns=8667.880419. Progress:282000/1000000
# Finished trajectory. Len=1000, Returns=8760.627715. Progress:283000/1000000
# Finished trajectory. Len=1000, Returns=8939.124467. Progress:284000/1000000
# Finished trajectory. Len=1000, Returns=8346.849860. Progress:285000/1000000
# Finished trajectory. Len=1000, Returns=8806.986788. Progress:286000/1000000
# Finished trajectory. Len=1000, Returns=8835.260155. Progress:287000/1000000
# Finished trajectory. Len=1000, Returns=8682.034681. Progress:288000/1000000
# Finished trajectory. Len=1000, Returns=2866.936831. Progress:289000/1000000
# Finished trajectory. Len=1000, Returns=8735.393344. Progress:290000/1000000
# Finished trajectory. Len=1000, Returns=8544.148915. Progress:291000/1000000
# Finished trajectory. Len=1000, Returns=8213.260682. Progress:292000/1000000
# Finished trajectory. Len=1000, Returns=9064.357979. Progress:293000/1000000
# Finished trajectory. Len=1000, Returns=8610.665770. Progress:294000/1000000
# Finished trajectory. Len=1000, Returns=9067.455918. Progress:295000/1000000
# Finished trajectory. Len=1000, Returns=7613.983710. Progress:296000/1000000
# Finished trajectory. Len=1000, Returns=8639.287009. Progress:297000/1000000
# Finished trajectory. Len=1000, Returns=8866.113721. Progress:298000/1000000
# Finished trajectory. Len=1000, Returns=9143.145582. Progress:299000/1000000
# Finished trajectory. Len=1000, Returns=8627.351040. Progress:300000/1000000
# Finished trajectory. Len=1000, Returns=8816.717356. Progress:301000/1000000
# Finished trajectory. Len=1000, Returns=8682.300424. Progress:302000/1000000
# Finished trajectory. Len=1000, Returns=8567.614244. Progress:303000/1000000
# Finished trajectory. Len=1000, Returns=8204.556854. Progress:304000/1000000
# Finished trajectory. Len=1000, Returns=8921.282256. Progress:305000/1000000
# Finished trajectory. Len=1000, Returns=8800.724789. Progress:306000/1000000
# Finished trajectory. Len=1000, Returns=8843.350631. Progress:307000/1000000
# Finished trajectory. Len=1000, Returns=8410.784179. Progress:308000/1000000
# Finished trajectory. Len=1000, Returns=8854.494057. Progress:309000/1000000
# Finished trajectory. Len=1000, Returns=8928.267589. Progress:310000/1000000
# Finished trajectory. Len=1000, Returns=8889.280877. Progress:311000/1000000
# Finished trajectory. Len=1000, Returns=8726.666043. Progress:312000/1000000
# Finished trajectory. Len=1000, Returns=9315.503978. Progress:313000/1000000
# Finished trajectory. Len=1000, Returns=9019.982938. Progress:314000/1000000
# Finished trajectory. Len=1000, Returns=9021.981665. Progress:315000/1000000
# Finished trajectory. Len=1000, Returns=8795.490714. Progress:316000/1000000
# Finished trajectory. Len=1000, Returns=8666.514296. Progress:317000/1000000
# Finished trajectory. Len=1000, Returns=8039.597703. Progress:318000/1000000
# Finished trajectory. Len=1000, Returns=8916.365904. Progress:319000/1000000
# Finished trajectory. Len=1000, Returns=9083.780308. Progress:320000/1000000
# Finished trajectory. Len=1000, Returns=8576.113030. Progress:321000/1000000
# Finished trajectory. Len=1000, Returns=8906.163533. Progress:322000/1000000
# Finished trajectory. Len=1000, Returns=8229.245376. Progress:323000/1000000
# Finished trajectory. Len=1000, Returns=8969.621224. Progress:324000/1000000
# Finished trajectory. Len=1000, Returns=9104.073707. Progress:325000/1000000
# Finished trajectory. Len=1000, Returns=8305.668195. Progress:326000/1000000
# Finished trajectory. Len=1000, Returns=8665.458739. Progress:327000/1000000
# Finished trajectory. Len=1000, Returns=8840.887294. Progress:328000/1000000
# Finished trajectory. Len=1000, Returns=8507.982833. Progress:329000/1000000
# Finished trajectory. Len=1000, Returns=8991.729734. Progress:330000/1000000
# Finished trajectory. Len=1000, Returns=8572.209134. Progress:331000/1000000
# Finished trajectory. Len=1000, Returns=8685.050243. Progress:332000/1000000
# Finished trajectory. Len=1000, Returns=8279.527146. Progress:333000/1000000
# Finished trajectory. Len=1000, Returns=8657.295900. Progress:334000/1000000
# Finished trajectory. Len=1000, Returns=8781.815981. Progress:335000/1000000
# Finished trajectory. Len=1000, Returns=8701.132079. Progress:336000/1000000
# Finished trajectory. Len=1000, Returns=6294.827175. Progress:337000/1000000
# Finished trajectory. Len=1000, Returns=8375.309938. Progress:338000/1000000
# Finished trajectory. Len=1000, Returns=8717.496790. Progress:339000/1000000
# Finished trajectory. Len=1000, Returns=862.192055. Progress:340000/1000000
# Finished trajectory. Len=1000, Returns=8692.125518. Progress:341000/1000000
# Finished trajectory. Len=1000, Returns=8962.507446. Progress:342000/1000000
# Finished trajectory. Len=1000, Returns=8690.093550. Progress:343000/1000000
# Finished trajectory. Len=1000, Returns=8632.841517. Progress:344000/1000000
# Finished trajectory. Len=1000, Returns=8763.475938. Progress:345000/1000000
# Finished trajectory. Len=1000, Returns=8515.645061. Progress:346000/1000000
# Finished trajectory. Len=1000, Returns=8085.594554. Progress:347000/1000000
# Finished trajectory. Len=1000, Returns=8515.879782. Progress:348000/1000000
# Finished trajectory. Len=1000, Returns=8432.550363. Progress:349000/1000000
# Finished trajectory. Len=1000, Returns=8660.719415. Progress:350000/1000000
# Finished trajectory. Len=1000, Returns=8671.460625. Progress:351000/1000000
# Finished trajectory. Len=1000, Returns=8698.743688. Progress:352000/1000000
# Finished trajectory. Len=1000, Returns=8891.720768. Progress:353000/1000000
# Finished trajectory. Len=1000, Returns=8839.098910. Progress:354000/1000000
# Finished trajectory. Len=1000, Returns=8531.510659. Progress:355000/1000000
# Finished trajectory. Len=1000, Returns=8945.982892. Progress:356000/1000000
# Finished trajectory. Len=1000, Returns=8754.625552. Progress:357000/1000000
# Finished trajectory. Len=1000, Returns=8343.136825. Progress:358000/1000000
# Finished trajectory. Len=1000, Returns=8034.670848. Progress:359000/1000000
# Finished trajectory. Len=1000, Returns=7415.497194. Progress:360000/1000000
# Finished trajectory. Len=1000, Returns=8740.228133. Progress:361000/1000000
# Finished trajectory. Len=1000, Returns=8816.428012. Progress:362000/1000000
# Finished trajectory. Len=1000, Returns=8151.198225. Progress:363000/1000000
# Finished trajectory. Len=1000, Returns=8358.659579. Progress:364000/1000000
# Finished trajectory. Len=1000, Returns=8204.848985. Progress:365000/1000000
# Finished trajectory. Len=1000, Returns=8384.716203. Progress:366000/1000000
# Finished trajectory. Len=1000, Returns=2770.120908. Progress:367000/1000000
# Finished trajectory. Len=1000, Returns=8895.594411. Progress:368000/1000000
# Finished trajectory. Len=1000, Returns=8857.399906. Progress:369000/1000000
# Finished trajectory. Len=1000, Returns=8442.532634. Progress:370000/1000000
# Finished trajectory. Len=1000, Returns=8675.563184. Progress:371000/1000000
# Finished trajectory. Len=1000, Returns=8448.948485. Progress:372000/1000000
# Finished trajectory. Len=1000, Returns=8638.828664. Progress:373000/1000000
# Finished trajectory. Len=1000, Returns=4420.868619. Progress:374000/1000000
# Finished trajectory. Len=1000, Returns=8797.148867. Progress:375000/1000000
# Finished trajectory. Len=1000, Returns=8784.869320. Progress:376000/1000000
# Finished trajectory. Len=1000, Returns=8552.966685. Progress:377000/1000000
# Finished trajectory. Len=1000, Returns=8864.951632. Progress:378000/1000000
# Finished trajectory. Len=1000, Returns=8932.056775. Progress:379000/1000000
# Finished trajectory. Len=1000, Returns=8550.601491. Progress:380000/1000000
# Finished trajectory. Len=1000, Returns=8639.881741. Progress:381000/1000000
# Finished trajectory. Len=1000, Returns=8442.856229. Progress:382000/1000000
# Finished trajectory. Len=1000, Returns=8720.331931. Progress:383000/1000000
# Finished trajectory. Len=1000, Returns=9341.665476. Progress:384000/1000000
# Finished trajectory. Len=1000, Returns=8530.873078. Progress:385000/1000000
# Finished trajectory. Len=1000, Returns=8693.058270. Progress:386000/1000000
# Finished trajectory. Len=1000, Returns=8786.076944. Progress:387000/1000000
# Finished trajectory. Len=1000, Returns=7838.798553. Progress:388000/1000000
# Finished trajectory. Len=1000, Returns=8713.481746. Progress:389000/1000000
# Finished trajectory. Len=1000, Returns=8925.059170. Progress:390000/1000000
# Finished trajectory. Len=1000, Returns=8920.093151. Progress:391000/1000000
# Finished trajectory. Len=1000, Returns=8554.224117. Progress:392000/1000000
# Finished trajectory. Len=1000, Returns=8671.233353. Progress:393000/1000000
# Finished trajectory. Len=1000, Returns=8941.479122. Progress:394000/1000000
# Finished trajectory. Len=1000, Returns=8466.034838. Progress:395000/1000000
# Finished trajectory. Len=1000, Returns=8975.175214. Progress:396000/1000000
# Finished trajectory. Len=1000, Returns=8761.142097. Progress:397000/1000000
# Finished trajectory. Len=1000, Returns=8293.038909. Progress:398000/1000000
# Finished trajectory. Len=1000, Returns=8316.227337. Progress:399000/1000000
# Finished trajectory. Len=1000, Returns=8643.430921. Progress:400000/1000000
# Finished trajectory. Len=1000, Returns=8927.595316. Progress:401000/1000000
# Finished trajectory. Len=1000, Returns=8960.662320. Progress:402000/1000000
# Finished trajectory. Len=1000, Returns=8770.222041. Progress:403000/1000000
# Finished trajectory. Len=1000, Returns=8557.904068. Progress:404000/1000000
# Finished trajectory. Len=1000, Returns=8772.415200. Progress:405000/1000000
# Finished trajectory. Len=1000, Returns=8760.722633. Progress:406000/1000000
# Finished trajectory. Len=1000, Returns=8734.920481. Progress:407000/1000000
# Finished trajectory. Len=1000, Returns=8927.540695. Progress:408000/1000000
# Finished trajectory. Len=1000, Returns=8529.855463. Progress:409000/1000000
# Finished trajectory. Len=1000, Returns=7411.305505. Progress:410000/1000000
# Finished trajectory. Len=1000, Returns=8605.687438. Progress:411000/1000000
# Finished trajectory. Len=1000, Returns=9143.672746. Progress:412000/1000000
# Finished trajectory. Len=1000, Returns=8950.808602. Progress:413000/1000000
# Finished trajectory. Len=1000, Returns=8391.630430. Progress:414000/1000000
# Finished trajectory. Len=1000, Returns=8780.881008. Progress:415000/1000000
# Finished trajectory. Len=1000, Returns=9079.311418. Progress:416000/1000000
# Finished trajectory. Len=1000, Returns=8570.350626. Progress:417000/1000000
# Finished trajectory. Len=1000, Returns=8917.531489. Progress:418000/1000000
# Finished trajectory. Len=1000, Returns=9001.321902. Progress:419000/1000000
# Finished trajectory. Len=1000, Returns=8586.190924. Progress:420000/1000000
# Finished trajectory. Len=1000, Returns=8723.432839. Progress:421000/1000000
# Finished trajectory. Len=1000, Returns=8810.998322. Progress:422000/1000000
# Finished trajectory. Len=1000, Returns=8886.247776. Progress:423000/1000000
# Finished trajectory. Len=1000, Returns=8907.458041. Progress:424000/1000000
# Finished trajectory. Len=1000, Returns=9163.709476. Progress:425000/1000000
# Finished trajectory. Len=1000, Returns=8756.043502. Progress:426000/1000000
# Finished trajectory. Len=1000, Returns=9097.754837. Progress:427000/1000000
# Finished trajectory. Len=1000, Returns=8771.658719. Progress:428000/1000000
# Finished trajectory. Len=1000, Returns=8686.086437. Progress:429000/1000000
# Finished trajectory. Len=1000, Returns=802.362562. Progress:430000/1000000
# Finished trajectory. Len=1000, Returns=8531.506506. Progress:431000/1000000
# Finished trajectory. Len=1000, Returns=8358.816354. Progress:432000/1000000
# Finished trajectory. Len=1000, Returns=8789.215525. Progress:433000/1000000
# Finished trajectory. Len=1000, Returns=8667.276290. Progress:434000/1000000
# Finished trajectory. Len=1000, Returns=8516.059029. Progress:435000/1000000
# Finished trajectory. Len=1000, Returns=8863.320521. Progress:436000/1000000
# Finished trajectory. Len=1000, Returns=1983.077757. Progress:437000/1000000
# Finished trajectory. Len=1000, Returns=7128.868549. Progress:438000/1000000
# Finished trajectory. Len=1000, Returns=8789.535623. Progress:439000/1000000
# Finished trajectory. Len=1000, Returns=8837.059554. Progress:440000/1000000
# Finished trajectory. Len=1000, Returns=8708.522364. Progress:441000/1000000
# Finished trajectory. Len=1000, Returns=8410.435116. Progress:442000/1000000
# Finished trajectory. Len=1000, Returns=8602.757289. Progress:443000/1000000
# Finished trajectory. Len=1000, Returns=8784.244379. Progress:444000/1000000
# Finished trajectory. Len=1000, Returns=8642.534115. Progress:445000/1000000
# Finished trajectory. Len=1000, Returns=8827.661135. Progress:446000/1000000
# Finished trajectory. Len=1000, Returns=8490.530334. Progress:447000/1000000
# Finished trajectory. Len=1000, Returns=4886.534429. Progress:448000/1000000
# Finished trajectory. Len=1000, Returns=8638.160761. Progress:449000/1000000
# Finished trajectory. Len=1000, Returns=8625.469178. Progress:450000/1000000
# Finished trajectory. Len=1000, Returns=8901.928828. Progress:451000/1000000
# Finished trajectory. Len=1000, Returns=8784.616886. Progress:452000/1000000
# Finished trajectory. Len=1000, Returns=8882.366166. Progress:453000/1000000
# Finished trajectory. Len=1000, Returns=8890.138626. Progress:454000/1000000
# Finished trajectory. Len=1000, Returns=8589.658547. Progress:455000/1000000
# Finished trajectory. Len=1000, Returns=8652.771031. Progress:456000/1000000
# Finished trajectory. Len=1000, Returns=8546.444273. Progress:457000/1000000
# Finished trajectory. Len=1000, Returns=8888.732841. Progress:458000/1000000
# Finished trajectory. Len=1000, Returns=8568.896799. Progress:459000/1000000
# Finished trajectory. Len=1000, Returns=8402.938256. Progress:460000/1000000
# Finished trajectory. Len=1000, Returns=8726.714885. Progress:461000/1000000
# Finished trajectory. Len=1000, Returns=8858.983188. Progress:462000/1000000
# Finished trajectory. Len=1000, Returns=1306.922344. Progress:463000/1000000
# Finished trajectory. Len=1000, Returns=8627.810673. Progress:464000/1000000
# Finished trajectory. Len=1000, Returns=9105.350449. Progress:465000/1000000
# Finished trajectory. Len=1000, Returns=8421.544329. Progress:466000/1000000
# Finished trajectory. Len=1000, Returns=4580.940553. Progress:467000/1000000
# Finished trajectory. Len=1000, Returns=2008.628574. Progress:468000/1000000
# Finished trajectory. Len=1000, Returns=8719.927001. Progress:469000/1000000
# Finished trajectory. Len=1000, Returns=8708.799636. Progress:470000/1000000
# Finished trajectory. Len=1000, Returns=8762.298337. Progress:471000/1000000
# Finished trajectory. Len=1000, Returns=8612.740577. Progress:472000/1000000
# Finished trajectory. Len=1000, Returns=8423.087996. Progress:473000/1000000
# Finished trajectory. Len=1000, Returns=8772.045563. Progress:474000/1000000
# Finished trajectory. Len=1000, Returns=8755.024429. Progress:475000/1000000
# Finished trajectory. Len=1000, Returns=8466.752307. Progress:476000/1000000
# Finished trajectory. Len=1000, Returns=8410.514472. Progress:477000/1000000
# Finished trajectory. Len=1000, Returns=6738.524868. Progress:478000/1000000
# Finished trajectory. Len=1000, Returns=8634.774976. Progress:479000/1000000
# Finished trajectory. Len=1000, Returns=8796.386520. Progress:480000/1000000
# Finished trajectory. Len=1000, Returns=8721.677110. Progress:481000/1000000
# Finished trajectory. Len=1000, Returns=8609.836544. Progress:482000/1000000
# Finished trajectory. Len=1000, Returns=8708.282740. Progress:483000/1000000
# Finished trajectory. Len=1000, Returns=8868.682104. Progress:484000/1000000
# Finished trajectory. Len=1000, Returns=8742.901793. Progress:485000/1000000
# Finished trajectory. Len=1000, Returns=8368.489082. Progress:486000/1000000
# Finished trajectory. Len=1000, Returns=8385.701790. Progress:487000/1000000
# Finished trajectory. Len=1000, Returns=8380.157957. Progress:488000/1000000
# Finished trajectory. Len=1000, Returns=8676.907730. Progress:489000/1000000
# Finished trajectory. Len=1000, Returns=8518.860786. Progress:490000/1000000
# Finished trajectory. Len=1000, Returns=8396.942397. Progress:491000/1000000
# Finished trajectory. Len=1000, Returns=8961.937215. Progress:492000/1000000
# Finished trajectory. Len=1000, Returns=8747.161657. Progress:493000/1000000
# Finished trajectory. Len=1000, Returns=1752.790187. Progress:494000/1000000
# Finished trajectory. Len=1000, Returns=8972.074294. Progress:495000/1000000
# Finished trajectory. Len=1000, Returns=8816.458599. Progress:496000/1000000
# Finished trajectory. Len=1000, Returns=7100.966749. Progress:497000/1000000
# Finished trajectory. Len=1000, Returns=8444.960153. Progress:498000/1000000
# Finished trajectory. Len=1000, Returns=8784.938892. Progress:499000/1000000
# Finished trajectory. Len=1000, Returns=8861.790771. Progress:500000/1000000
# Finished trajectory. Len=1000, Returns=8650.065338. Progress:501000/1000000
# Finished trajectory. Len=1000, Returns=6643.055819. Progress:502000/1000000
# Finished trajectory. Len=1000, Returns=8672.025902. Progress:503000/1000000
# Finished trajectory. Len=1000, Returns=8904.537634. Progress:504000/1000000
# Finished trajectory. Len=1000, Returns=798.498243. Progress:505000/1000000
# Finished trajectory. Len=1000, Returns=8581.178433. Progress:506000/1000000
# Finished trajectory. Len=1000, Returns=8328.274818. Progress:507000/1000000
# Finished trajectory. Len=1000, Returns=7702.060798. Progress:508000/1000000
# Finished trajectory. Len=1000, Returns=8839.298687. Progress:509000/1000000
# Finished trajectory. Len=1000, Returns=8813.206730. Progress:510000/1000000
# Finished trajectory. Len=1000, Returns=8456.144676. Progress:511000/1000000
# Finished trajectory. Len=1000, Returns=8074.129023. Progress:512000/1000000
# Finished trajectory. Len=1000, Returns=9017.844546. Progress:513000/1000000
# Finished trajectory. Len=1000, Returns=8755.469881. Progress:514000/1000000
# Finished trajectory. Len=1000, Returns=8870.259104. Progress:515000/1000000
# Finished trajectory. Len=1000, Returns=8902.869171. Progress:516000/1000000
# Finished trajectory. Len=1000, Returns=8628.310727. Progress:517000/1000000
# Finished trajectory. Len=1000, Returns=8504.131334. Progress:518000/1000000
# Finished trajectory. Len=1000, Returns=8323.858069. Progress:519000/1000000
# Finished trajectory. Len=1000, Returns=8713.687978. Progress:520000/1000000
# Finished trajectory. Len=1000, Returns=8751.292016. Progress:521000/1000000
# Finished trajectory. Len=1000, Returns=8143.367642. Progress:522000/1000000
# Finished trajectory. Len=1000, Returns=8675.070658. Progress:523000/1000000
# Finished trajectory. Len=1000, Returns=8971.823579. Progress:524000/1000000
# Finished trajectory. Len=1000, Returns=8758.671179. Progress:525000/1000000
# Finished trajectory. Len=1000, Returns=8874.868386. Progress:526000/1000000
# Finished trajectory. Len=1000, Returns=8837.826354. Progress:527000/1000000
# Finished trajectory. Len=1000, Returns=8625.650229. Progress:528000/1000000
# Finished trajectory. Len=1000, Returns=8562.624105. Progress:529000/1000000
# Finished trajectory. Len=1000, Returns=8285.485805. Progress:530000/1000000
# Finished trajectory. Len=1000, Returns=8490.267032. Progress:531000/1000000
# Finished trajectory. Len=1000, Returns=8701.060654. Progress:532000/1000000
# Finished trajectory. Len=1000, Returns=8474.711392. Progress:533000/1000000
# Finished trajectory. Len=1000, Returns=8144.081089. Progress:534000/1000000
# Finished trajectory. Len=1000, Returns=8721.058085. Progress:535000/1000000
# Finished trajectory. Len=1000, Returns=9078.905280. Progress:536000/1000000
# Finished trajectory. Len=1000, Returns=8581.945736. Progress:537000/1000000
# Finished trajectory. Len=1000, Returns=8607.845402. Progress:538000/1000000
# Finished trajectory. Len=1000, Returns=5322.849949. Progress:539000/1000000
# Finished trajectory. Len=1000, Returns=8907.711108. Progress:540000/1000000
# Finished trajectory. Len=1000, Returns=9022.645246. Progress:541000/1000000
# Finished trajectory. Len=1000, Returns=8824.090066. Progress:542000/1000000
# Finished trajectory. Len=1000, Returns=8544.897341. Progress:543000/1000000
# Finished trajectory. Len=1000, Returns=8395.238629. Progress:544000/1000000
# Finished trajectory. Len=1000, Returns=8872.340246. Progress:545000/1000000
# Finished trajectory. Len=1000, Returns=8537.730184. Progress:546000/1000000
# Finished trajectory. Len=1000, Returns=9101.080166. Progress:547000/1000000
# Finished trajectory. Len=1000, Returns=8793.238765. Progress:548000/1000000
# Finished trajectory. Len=1000, Returns=8532.700892. Progress:549000/1000000
# Finished trajectory. Len=1000, Returns=8786.332214. Progress:550000/1000000
# Finished trajectory. Len=1000, Returns=8788.105721. Progress:551000/1000000
# Finished trajectory. Len=1000, Returns=8445.360118. Progress:552000/1000000
# Finished trajectory. Len=1000, Returns=8641.629090. Progress:553000/1000000
# Finished trajectory. Len=1000, Returns=8793.165568. Progress:554000/1000000
# Finished trajectory. Len=1000, Returns=8562.938768. Progress:555000/1000000
# Finished trajectory. Len=1000, Returns=7442.376545. Progress:556000/1000000
# Finished trajectory. Len=1000, Returns=8890.927599. Progress:557000/1000000
# Finished trajectory. Len=1000, Returns=8587.900590. Progress:558000/1000000
# Finished trajectory. Len=1000, Returns=8912.985146. Progress:559000/1000000
# Finished trajectory. Len=1000, Returns=8343.176758. Progress:560000/1000000
# Finished trajectory. Len=1000, Returns=8117.762048. Progress:561000/1000000
# Finished trajectory. Len=1000, Returns=8297.454346. Progress:562000/1000000
# Finished trajectory. Len=1000, Returns=8914.931875. Progress:563000/1000000
# Finished trajectory. Len=1000, Returns=8427.668021. Progress:564000/1000000
# Finished trajectory. Len=1000, Returns=8592.329714. Progress:565000/1000000
# Finished trajectory. Len=1000, Returns=8629.156761. Progress:566000/1000000
# Finished trajectory. Len=1000, Returns=8289.937511. Progress:567000/1000000
# Finished trajectory. Len=1000, Returns=9022.192377. Progress:568000/1000000
# Finished trajectory. Len=1000, Returns=8558.783360. Progress:569000/1000000
# Finished trajectory. Len=1000, Returns=8908.307468. Progress:570000/1000000
# Finished trajectory. Len=1000, Returns=8592.451202. Progress:571000/1000000
# Finished trajectory. Len=1000, Returns=8686.417521. Progress:572000/1000000
# Finished trajectory. Len=1000, Returns=8408.313620. Progress:573000/1000000
# Finished trajectory. Len=1000, Returns=8535.853484. Progress:574000/1000000
# Finished trajectory. Len=1000, Returns=9133.790566. Progress:575000/1000000
# Finished trajectory. Len=1000, Returns=8680.755357. Progress:576000/1000000
# Finished trajectory. Len=1000, Returns=8825.524350. Progress:577000/1000000
# Finished trajectory. Len=1000, Returns=8461.895193. Progress:578000/1000000
# Finished trajectory. Len=1000, Returns=8677.612989. Progress:579000/1000000
# Finished trajectory. Len=1000, Returns=8699.799110. Progress:580000/1000000
# Finished trajectory. Len=1000, Returns=8747.048623. Progress:581000/1000000
# Finished trajectory. Len=1000, Returns=8946.826580. Progress:582000/1000000
# Finished trajectory. Len=1000, Returns=7222.085815. Progress:583000/1000000
# Finished trajectory. Len=1000, Returns=8754.665355. Progress:584000/1000000
# Finished trajectory. Len=1000, Returns=7940.134377. Progress:585000/1000000
# Finished trajectory. Len=1000, Returns=8530.202534. Progress:586000/1000000
# Finished trajectory. Len=1000, Returns=8199.839660. Progress:587000/1000000
# Finished trajectory. Len=1000, Returns=8544.331949. Progress:588000/1000000
# Finished trajectory. Len=1000, Returns=8617.855432. Progress:589000/1000000
# Finished trajectory. Len=1000, Returns=8649.153731. Progress:590000/1000000
# Finished trajectory. Len=1000, Returns=8996.920255. Progress:591000/1000000
# Finished trajectory. Len=1000, Returns=8912.758886. Progress:592000/1000000
# Finished trajectory. Len=1000, Returns=8778.871588. Progress:593000/1000000
# Finished trajectory. Len=1000, Returns=8736.527912. Progress:594000/1000000
# Finished trajectory. Len=1000, Returns=8522.984346. Progress:595000/1000000
# Finished trajectory. Len=1000, Returns=3117.143196. Progress:596000/1000000
# Finished trajectory. Len=1000, Returns=4274.037894. Progress:597000/1000000
# Finished trajectory. Len=1000, Returns=8843.550786. Progress:598000/1000000
# Finished trajectory. Len=1000, Returns=8766.872264. Progress:599000/1000000
# Finished trajectory. Len=1000, Returns=8880.010616. Progress:600000/1000000
# Finished trajectory. Len=1000, Returns=8547.282452. Progress:601000/1000000
# Finished trajectory. Len=1000, Returns=8478.553263. Progress:602000/1000000
# Finished trajectory. Len=1000, Returns=9037.958840. Progress:603000/1000000
# Finished trajectory. Len=1000, Returns=8612.108386. Progress:604000/1000000
# Finished trajectory. Len=1000, Returns=8566.070377. Progress:605000/1000000
# Finished trajectory. Len=1000, Returns=8718.667430. Progress:606000/1000000
# Finished trajectory. Len=1000, Returns=8853.347987. Progress:607000/1000000
# Finished trajectory. Len=1000, Returns=8424.205609. Progress:608000/1000000
# Finished trajectory. Len=1000, Returns=8304.401852. Progress:609000/1000000
# Finished trajectory. Len=1000, Returns=8742.793070. Progress:610000/1000000
# Finished trajectory. Len=1000, Returns=8787.628899. Progress:611000/1000000
# Finished trajectory. Len=1000, Returns=8252.272968. Progress:612000/1000000
# Finished trajectory. Len=1000, Returns=8635.064021. Progress:613000/1000000
# Finished trajectory. Len=1000, Returns=9163.286365. Progress:614000/1000000
# Finished trajectory. Len=1000, Returns=8663.917836. Progress:615000/1000000
# Finished trajectory. Len=1000, Returns=8971.400143. Progress:616000/1000000
# Finished trajectory. Len=1000, Returns=8939.522644. Progress:617000/1000000
# Finished trajectory. Len=1000, Returns=8682.519659. Progress:618000/1000000
# Finished trajectory. Len=1000, Returns=8718.784611. Progress:619000/1000000
# Finished trajectory. Len=1000, Returns=8196.295099. Progress:620000/1000000
# Finished trajectory. Len=1000, Returns=8505.975991. Progress:621000/1000000
# Finished trajectory. Len=1000, Returns=8557.367271. Progress:622000/1000000
# Finished trajectory. Len=1000, Returns=8652.677570. Progress:623000/1000000
# Finished trajectory. Len=1000, Returns=8662.464583. Progress:624000/1000000
# Finished trajectory. Len=1000, Returns=8680.231577. Progress:625000/1000000
# Finished trajectory. Len=1000, Returns=8952.165357. Progress:626000/1000000
# Finished trajectory. Len=1000, Returns=8893.473298. Progress:627000/1000000
# Finished trajectory. Len=1000, Returns=8550.295769. Progress:628000/1000000
# Finished trajectory. Len=1000, Returns=8900.448290. Progress:629000/1000000
# Finished trajectory. Len=1000, Returns=8704.518185. Progress:630000/1000000
# Finished trajectory. Len=1000, Returns=8586.142245. Progress:631000/1000000
# Finished trajectory. Len=1000, Returns=8902.988544. Progress:632000/1000000
# ...
# Finished trajectory. Len=1000, Returns=8439.297330. Progress:790000/1000000
# Finished trajectory. Len=1000, Returns=8614.840894. Progress:791000/1000000
# Finished trajectory. Len=1000, Returns=9099.648575. Progress:792000/1000000
# Finished trajectory. Len=1000, Returns=7647.121129. Progress:793000/1000000
# Finished trajectory. Len=1000, Returns=8880.444106. Progress:794000/1000000
# Finished trajectory. Len=1000, Returns=8743.745960. Progress:795000/1000000
# Finished trajectory. Len=1000, Returns=8543.429313. Progress:796000/1000000
# Finished trajectory. Len=1000, Returns=8291.908489. Progress:797000/1000000
# Finished trajectory. Len=1000, Returns=8731.710276. Progress:798000/1000000
# Finished trajectory. Len=1000, Returns=8441.067915. Progress:799000/1000000
# Finished trajectory. Len=1000, Returns=8422.691938. Progress:800000/1000000
# Finished trajectory. Len=1000, Returns=8545.659913. Progress:801000/1000000
# Finished trajectory. Len=1000, Returns=8490.477385. Progress:802000/1000000
# Finished trajectory. Len=1000, Returns=8863.511764. Progress:803000/1000000
# Finished trajectory. Len=1000, Returns=8769.392095. Progress:804000/1000000
# Finished trajectory. Len=1000, Returns=8459.622491. Progress:805000/1000000
# Finished trajectory. Len=1000, Returns=8832.974070. Progress:806000/1000000
# Finished trajectory. Len=1000, Returns=8466.822804. Progress:807000/1000000
# Finished trajectory. Len=1000, Returns=8470.840976. Progress:808000/1000000
# Finished trajectory. Len=1000, Returns=8146.953474. Progress:809000/1000000
# Finished trajectory. Len=1000, Returns=8419.644046. Progress:810000/1000000
# Finished trajectory. Len=1000, Returns=8795.164856. Progress:811000/1000000
# Finished trajectory. Len=1000, Returns=8135.557786. Progress:812000/1000000
# Finished trajectory. Len=1000, Returns=8886.091335. Progress:813000/1000000
# Finished trajectory. Len=1000, Returns=8558.593451. Progress:814000/1000000
# Finished trajectory. Len=1000, Returns=8892.614479. Progress:815000/1000000
# Finished trajectory. Len=1000, Returns=8494.573691. Progress:816000/1000000
# Finished trajectory. Len=1000, Returns=8760.572993. Progress:817000/1000000
# Finished trajectory. Len=1000, Returns=9372.850661. Progress:818000/1000000
# Finished trajectory. Len=1000, Returns=8829.852069. Progress:819000/1000000
# Finished trajectory. Len=1000, Returns=8671.469770. Progress:820000/1000000
# Finished trajectory. Len=1000, Returns=8937.542077. Progress:821000/1000000
# Finished trajectory. Len=1000, Returns=8777.504438. Progress:822000/1000000
# Finished trajectory. Len=1000, Returns=7703.056277. Progress:823000/1000000
# Finished trajectory. Len=1000, Returns=8611.513383. Progress:824000/1000000
# Finished trajectory. Len=1000, Returns=8890.553596. Progress:825000/1000000
# Finished trajectory. Len=1000, Returns=8124.621983. Progress:826000/1000000
# Finished trajectory. Len=1000, Returns=8738.249570. Progress:827000/1000000
# Finished trajectory. Len=1000, Returns=8382.932595. Progress:828000/1000000
# Finished trajectory. Len=1000, Returns=8540.272690. Progress:829000/1000000
# Finished trajectory. Len=1000, Returns=8989.198710. Progress:830000/1000000
# Finished trajectory. Len=1000, Returns=8849.455834. Progress:831000/1000000
# Finished trajectory. Len=1000, Returns=8755.872621. Progress:832000/1000000
# Finished trajectory. Len=1000, Returns=8732.694849. Progress:833000/1000000
# Finished trajectory. Len=1000, Returns=8204.159939. Progress:834000/1000000
# Finished trajectory. Len=1000, Returns=8388.586037. Progress:835000/1000000
# Finished trajectory. Len=1000, Returns=8626.098938. Progress:836000/1000000
# Finished trajectory. Len=1000, Returns=8671.575727. Progress:837000/1000000
# Finished trajectory. Len=1000, Returns=8587.347667. Progress:838000/1000000
# Finished trajectory. Len=1000, Returns=8560.583544. Progress:839000/1000000
# Finished trajectory. Len=1000, Returns=8836.896668. Progress:840000/1000000
# Finished trajectory. Len=1000, Returns=8648.388976. Progress:841000/1000000
# Finished trajectory. Len=1000, Returns=8776.854511. Progress:842000/1000000
# Finished trajectory. Len=1000, Returns=8796.990217. Progress:843000/1000000
# Finished trajectory. Len=1000, Returns=8814.913498. Progress:844000/1000000
# Finished trajectory. Len=1000, Returns=8738.949759. Progress:845000/1000000
# Finished trajectory. Len=1000, Returns=8733.916927. Progress:846000/1000000
# Finished trajectory. Len=1000, Returns=8392.561367. Progress:847000/1000000
# Finished trajectory. Len=1000, Returns=8679.522914. Progress:848000/1000000
# Finished trajectory. Len=1000, Returns=9025.345285. Progress:849000/1000000
# Finished trajectory. Len=1000, Returns=8802.403355. Progress:850000/1000000
# Finished trajectory. Len=1000, Returns=319.705813. Progress:851000/1000000
# Finished trajectory. Len=1000, Returns=9134.373854. Progress:852000/1000000
# Finished trajectory. Len=1000, Returns=8517.491270. Progress:853000/1000000
# Finished trajectory. Len=1000, Returns=8532.444648. Progress:854000/1000000
# Finished trajectory. Len=1000, Returns=9156.599788. Progress:855000/1000000
# Finished trajectory. Len=1000, Returns=8126.390417. Progress:856000/1000000
# Finished trajectory. Len=1000, Returns=8296.075762. Progress:857000/1000000
# Finished trajectory. Len=1000, Returns=8586.968260. Progress:858000/1000000
# Finished trajectory. Len=1000, Returns=8763.910308. Progress:859000/1000000
# Finished trajectory. Len=1000, Returns=8936.136480. Progress:860000/1000000
# Finished trajectory. Len=1000, Returns=8490.068485. Progress:861000/1000000
# Finished trajectory. Len=1000, Returns=8822.321190. Progress:862000/1000000
# Finished trajectory. Len=1000, Returns=7755.256201. Progress:863000/1000000
# Finished trajectory. Len=1000, Returns=9063.929122. Progress:864000/1000000
# Finished trajectory. Len=1000, Returns=8863.057775. Progress:865000/1000000
# Finished trajectory. Len=1000, Returns=8851.153643. Progress:866000/1000000
# Finished trajectory. Len=1000, Returns=8483.797883. Progress:867000/1000000
# Finished trajectory. Len=1000, Returns=8816.974829. Progress:868000/1000000
# Finished trajectory. Len=1000, Returns=8526.479542. Progress:869000/1000000
# Finished trajectory. Len=1000, Returns=8879.834833. Progress:870000/1000000
# Finished trajectory. Len=1000, Returns=8827.408897. Progress:871000/1000000
# Finished trajectory. Len=1000, Returns=6003.884868. Progress:872000/1000000
# Finished trajectory. Len=1000, Returns=8919.962063. Progress:873000/1000000
# Finished trajectory. Len=1000, Returns=8705.797562. Progress:874000/1000000
# Finished trajectory. Len=1000, Returns=9065.969601. Progress:875000/1000000
# Finished trajectory. Len=1000, Returns=8519.839557. Progress:876000/1000000
# Finished trajectory. Len=1000, Returns=8902.539726. Progress:877000/1000000
# Finished trajectory. Len=1000, Returns=8679.687372. Progress:878000/1000000
# Finished trajectory. Len=1000, Returns=5585.505411. Progress:879000/1000000
# Finished trajectory. Len=1000, Returns=8675.395418. Progress:880000/1000000
# Finished trajectory. Len=1000, Returns=8613.088190. Progress:881000/1000000
# Finished trajectory. Len=1000, Returns=8743.742821. Progress:882000/1000000
# Finished trajectory. Len=1000, Returns=8669.500990. Progress:883000/1000000
# Finished trajectory. Len=1000, Returns=8591.952873. Progress:884000/1000000
# Finished trajectory. Len=1000, Returns=8711.179093. Progress:885000/1000000
# Finished trajectory. Len=1000, Returns=8858.676760. Progress:886000/1000000
# Finished trajectory. Len=1000, Returns=8796.055185. Progress:887000/1000000
# Finished trajectory. Len=1000, Returns=8639.388378. Progress:888000/1000000
# Finished trajectory. Len=1000, Returns=7655.941025. Progress:889000/1000000
# Finished trajectory. Len=1000, Returns=8406.516889. Progress:890000/1000000
# Finished trajectory. Len=1000, Returns=8942.583331. Progress:891000/1000000
# Finished trajectory. Len=1000, Returns=9122.494769. Progress:892000/1000000
# Finished trajectory. Len=1000, Returns=8055.925722. Progress:893000/1000000
# Finished trajectory. Len=1000, Returns=8257.691087. Progress:894000/1000000
# Finished trajectory. Len=1000, Returns=8549.057377. Progress:895000/1000000
# Finished trajectory. Len=1000, Returns=6777.800518. Progress:896000/1000000
# Finished trajectory. Len=1000, Returns=8335.144311. Progress:897000/1000000
# Finished trajectory. Len=1000, Returns=8099.166657. Progress:898000/1000000
# Finished trajectory. Len=1000, Returns=8433.497500. Progress:899000/1000000
# Finished trajectory. Len=1000, Returns=8711.062041. Progress:900000/1000000
# Finished trajectory. Len=1000, Returns=8248.177070. Progress:901000/1000000
# Finished trajectory. Len=1000, Returns=4398.493335. Progress:902000/1000000
# Finished trajectory. Len=1000, Returns=8793.364014. Progress:903000/1000000
# Finished trajectory. Len=1000, Returns=8744.452266. Progress:904000/1000000
# Finished trajectory. Len=1000, Returns=9009.351309. Progress:905000/1000000
# Finished trajectory. Len=1000, Returns=7844.453483. Progress:906000/1000000
# Finished trajectory. Len=1000, Returns=8526.089753. Progress:907000/1000000
# Finished trajectory. Len=1000, Returns=8848.801195. Progress:908000/1000000
# Finished trajectory. Len=1000, Returns=8390.490055. Progress:909000/1000000
# Finished trajectory. Len=1000, Returns=8723.501086. Progress:910000/1000000
# Finished trajectory. Len=1000, Returns=8861.893776. Progress:911000/1000000
# Finished trajectory. Len=1000, Returns=8845.120849. Progress:912000/1000000
# Finished trajectory. Len=1000, Returns=8611.403333. Progress:913000/1000000
# Finished trajectory. Len=1000, Returns=8771.357065. Progress:914000/1000000
# Finished trajectory. Len=1000, Returns=9030.918654. Progress:915000/1000000
# Finished trajectory. Len=1000, Returns=8285.860669. Progress:916000/1000000
# Finished trajectory. Len=1000, Returns=7121.329770. Progress:917000/1000000
# Finished trajectory. Len=1000, Returns=8556.333055. Progress:918000/1000000
# Finished trajectory. Len=1000, Returns=8399.305046. Progress:919000/1000000
# Finished trajectory. Len=1000, Returns=9043.871461. Progress:920000/1000000
# Finished trajectory. Len=1000, Returns=8767.965283. Progress:921000/1000000
# Finished trajectory. Len=1000, Returns=8068.502470. Progress:922000/1000000
# Finished trajectory. Len=1000, Returns=8358.761593. Progress:923000/1000000
# Finished trajectory. Len=1000, Returns=8892.120051. Progress:924000/1000000
# Finished trajectory. Len=1000, Returns=8408.363182. Progress:925000/1000000
# Finished trajectory. Len=1000, Returns=8844.301712. Progress:926000/1000000
# Finished trajectory. Len=1000, Returns=8812.610841. Progress:927000/1000000
# Finished trajectory. Len=1000, Returns=8450.694027. Progress:928000/1000000
# Finished trajectory. Len=1000, Returns=8894.690117. Progress:929000/1000000
# Finished trajectory. Len=1000, Returns=9070.233175. Progress:930000/1000000
# Finished trajectory. Len=1000, Returns=8646.170565. Progress:931000/1000000
# Finished trajectory. Len=1000, Returns=8514.710686. Progress:932000/1000000
# Finished trajectory. Len=1000, Returns=8567.036989. Progress:933000/1000000
# Finished trajectory. Len=1000, Returns=8828.407987. Progress:934000/1000000
# Finished trajectory. Len=1000, Returns=8640.981520. Progress:935000/1000000
# Finished trajectory. Len=1000, Returns=9049.432224. Progress:936000/1000000
# Finished trajectory. Len=1000, Returns=7522.010013. Progress:937000/1000000
# Finished trajectory. Len=1000, Returns=8801.039874. Progress:938000/1000000
# Finished trajectory. Len=1000, Returns=8521.378174. Progress:939000/1000000
# Finished trajectory. Len=1000, Returns=9066.513843. Progress:940000/1000000
# Finished trajectory. Len=1000, Returns=8610.658516. Progress:941000/1000000
# Finished trajectory. Len=1000, Returns=8605.416898. Progress:942000/1000000
# Finished trajectory. Len=1000, Returns=8776.205472. Progress:943000/1000000
# Finished trajectory. Len=1000, Returns=8975.319089. Progress:944000/1000000
# Finished trajectory. Len=1000, Returns=8937.038417. Progress:945000/1000000
# Finished trajectory. Len=1000, Returns=8570.080369. Progress:946000/1000000
# Finished trajectory. Len=1000, Returns=8659.517503. Progress:947000/1000000
# Finished trajectory. Len=1000, Returns=2981.440812. Progress:948000/1000000
# Finished trajectory. Len=1000, Returns=8351.447565. Progress:949000/1000000
# Finished trajectory. Len=1000, Returns=8751.293740. Progress:950000/1000000
# Finished trajectory. Len=1000, Returns=9108.044003. Progress:951000/1000000
# Finished trajectory. Len=1000, Returns=8436.103139. Progress:952000/1000000
# Finished trajectory. Len=1000, Returns=8645.958839. Progress:953000/1000000
# Finished trajectory. Len=1000, Returns=8599.996553. Progress:954000/1000000
# Finished trajectory. Len=1000, Returns=8713.895195. Progress:955000/1000000
# Finished trajectory. Len=1000, Returns=8730.601811. Progress:956000/1000000
# Finished trajectory. Len=1000, Returns=8720.213237. Progress:957000/1000000
# Finished trajectory. Len=1000, Returns=8971.979392. Progress:958000/1000000
# Finished trajectory. Len=1000, Returns=8317.268974. Progress:959000/1000000
# Finished trajectory. Len=1000, Returns=8621.462443. Progress:960000/1000000
# Finished trajectory. Len=1000, Returns=8644.717218. Progress:961000/1000000
# Finished trajectory. Len=1000, Returns=8872.656575. Progress:962000/1000000
# Finished trajectory. Len=1000, Returns=8784.668890. Progress:963000/1000000
# Finished trajectory. Len=1000, Returns=8622.897900. Progress:964000/1000000
# Finished trajectory. Len=1000, Returns=8779.570600. Progress:965000/1000000
# Finished trajectory. Len=1000, Returns=5437.743392. Progress:966000/1000000
# Finished trajectory. Len=1000, Returns=8522.380246. Progress:967000/1000000
# Finished trajectory. Len=1000, Returns=8658.175042. Progress:968000/1000000
# Finished trajectory. Len=1000, Returns=8516.758086. Progress:969000/1000000
# Finished trajectory. Len=1000, Returns=8679.065010. Progress:970000/1000000
# Finished trajectory. Len=1000, Returns=8321.633689. Progress:971000/1000000
# Finished trajectory. Len=1000, Returns=8771.313301. Progress:972000/1000000
# Finished trajectory. Len=1000, Returns=8518.779811. Progress:973000/1000000
# Finished trajectory. Len=1000, Returns=8167.112415. Progress:974000/1000000
# Finished trajectory. Len=1000, Returns=8482.840152. Progress:975000/1000000
# Finished trajectory. Len=1000, Returns=9078.775536. Progress:976000/1000000
# Finished trajectory. Len=1000, Returns=8528.634194. Progress:977000/1000000
# Finished trajectory. Len=1000, Returns=8092.663419. Progress:978000/1000000
# Finished trajectory. Len=1000, Returns=8920.567245. Progress:979000/1000000
# Finished trajectory. Len=1000, Returns=8966.773368. Progress:980000/1000000
# Finished trajectory. Len=1000, Returns=8006.540115. Progress:981000/1000000
# Finished trajectory. Len=1000, Returns=3318.699363. Progress:982000/1000000
# Finished trajectory. Len=1000, Returns=8433.186614. Progress:983000/1000000
# Finished trajectory. Len=1000, Returns=8776.133017. Progress:984000/1000000
# Finished trajectory. Len=1000, Returns=8240.530792. Progress:985000/1000000
# Finished trajectory. Len=1000, Returns=8921.914482. Progress:986000/1000000
# Finished trajectory. Len=1000, Returns=7612.204861. Progress:987000/1000000
# Finished trajectory. Len=1000, Returns=8930.013475. Progress:988000/1000000
# Finished trajectory. Len=1000, Returns=8945.057135. Progress:989000/1000000
# Finished trajectory. Len=1000, Returns=8817.149481. Progress:990000/1000000
# Finished trajectory. Len=1000, Returns=732.354778. Progress:991000/1000000
# Finished trajectory. Len=1000, Returns=8934.346311. Progress:992000/1000000
# Finished trajectory. Len=1000, Returns=8719.547531. Progress:993000/1000000
# Finished trajectory. Len=1000, Returns=9030.141582. Progress:994000/1000000
# Finished trajectory. Len=1000, Returns=8327.482933. Progress:995000/1000000
# Finished trajectory. Len=1000, Returns=8900.158919. Progress:996000/1000000
# Finished trajectory. Len=1000, Returns=8566.597185. Progress:997000/1000000
# Finished trajectory. Len=1000, Returns=8580.569341. Progress:998000/1000000
# Finished trajectory. Len=1000, Returns=8534.822358. Progress:999000/1000000

# %%
type(dataset)
# Out:
# dict

# %%
save_data_to_h5_file(dataset, str(PROJECT_ROOT_DIR / "rollout" / "data" / "iter_1" / (ENV_NAME + ".hdf5")))

# %%
from load_data import load_data
dataset = load_data(str(PROJECT_ROOT_DIR / "rollout" / "data" / "iter_1" / "halfcheetah-medium-v2.hdf5"))
dataset
# Out:
# load datafile: 100%|██████████| 9/9 [00:01<00:00,  7.36it/s]
# {'actions': array([[-2.7080185 , -2.6794457 , -1.6466984 , -0.32171828,  1.073822  ,
#          -2.1104696 ],
#         [-2.6991408 , -7.7600427 , -3.3680508 ,  1.734412  ,  3.9231396 ,
#          -3.1123872 ],
#         [-1.0118772 , -6.1386895 , -2.696664  ,  0.12804973,  0.3074389 ,
#          -6.086974  ],
#         ...,
#         [ 5.797638  , -6.3652377 ,  2.6264303 , -7.982745  , -1.4834342 ,
#          -0.3839617 ],
#         [ 4.7952642 , -1.6870061 ,  4.5005126 , -1.7202296 ,  0.44820648,
#          -3.5511632 ],
#         [-0.30733508, -0.08453444, -1.7232296 ,  1.9518642 ,  3.590275  ,
#          -5.921312  ]], dtype=float32),
#  'infos/action_log_probs': array([ 0.20974946, -1.9796014 , -1.7800721 , ..., -1.932462  ,
#         -2.0694394 , -2.683373  ], dtype=float32),
#  'infos/qpos': array([[ 8.2355320e-02, -8.1376303e-03,  4.4860616e-02, ...,
#           9.2879459e-02, -8.5313469e-02, -3.4639064e-02],
#         [ 5.6556515e-02, -1.9722346e-03,  7.6817654e-02, ...,
#          -1.8007116e-01,  3.3974579e-01, -3.1771627e-01],
#         [ 4.7532637e-02, -5.2414011e-02,  6.4409390e-02, ...,
#           9.2319094e-02,  4.4349918e-01, -5.3487206e-01],
#         ...,
#         [ 4.5273679e+02,  2.7850175e-02,  3.9132863e-02, ...,
#          -3.5765156e-01,  6.7063403e-01,  5.5453128e-01],
#         [ 4.5322064e+02, -3.2764231e-03,  1.5020066e-01, ...,
#          -7.8916781e-02,  7.6968312e-02,  1.8673787e-01],
#         [ 4.5369958e+02, -5.3812519e-02,  2.4020723e-01, ...,
#          -4.0064579e-01,  9.6071325e-03, -4.5042819e-01]], dtype=float32),
#  'infos/qvel': array([[  0.04969082,   0.07137247,  -0.1385781 , ...,  -0.06772373,
#           -0.10413683,   0.03550119],
#         [ -0.77936244,  -0.11929665,   0.8129363 , ...,  -6.529823  ,
#           10.396423  ,  -7.601937  ],
#         [  0.16690242,  -1.5516696 ,  -0.8561644 , ...,  11.036896  ,
#           -1.3423414 ,   1.0436975 ],
#         ...,
#         [  9.309753  ,  -0.81423724,   0.7399464 , ...,   6.394158  ,
#            1.6424845 ,  -1.5810374 ],
#         [  9.831437  ,  -0.962252  ,   2.1598387 , ...,   3.061461  ,
#          -14.822631  ,  -9.403476  ],
#         [  9.334722  ,  -1.3835531 ,   1.1383259 , ..., -10.118945  ,
#            4.3513374 , -12.55234   ]], dtype=float32),
#  'next_observations': array([[ 0.8893898 ,  0.19967468, -0.11915976, ..., -0.6241651 ,
#           1.8315501 , -1.0153198 ],
#         [ 0.21462324,  0.15865663, -0.9903769 , ...,  1.0378295 ,
#          -0.23760185,  0.13736774],
#         [-0.8207876 ,  0.05957367, -1.1917659 , ...,  0.37796655,
#          -0.22271736,  0.20446587],
#         ...,
#         [ 0.8719435 ,  0.4422574 ,  0.23025587, ...,  0.2832703 ,
#          -2.6137264 , -1.2555118 ],
#         [ 0.19591519,  0.73979264,  1.9176445 , ..., -0.9637335 ,
#           0.7660035 , -1.6753371 ],
#         [-0.6511722 ,  0.4637181 ,  2.355488  , ...,  1.0475149 ,
#          -1.3675753 ,  0.23313548]], dtype=float32),
#  'observations': array([[ 0.80691445,  0.09403411,  0.3445566 , ..., -0.01278318,
#          -0.01934776,  0.00294899],
#         [ 0.8893898 ,  0.19967468, -0.11915976, ..., -0.6241651 ,
#           1.8315501 , -1.0153198 ],
#         [ 0.21462324,  0.15865663, -0.9903769 , ...,  1.0378295 ,
#          -0.23760185,  0.13736774],
#         ...,
#         [ 1.2883283 ,  0.07509985, -1.1815304 , ...,  0.59857816,
#           0.28852323, -0.21257758],
#         [ 0.8719435 ,  0.4422574 ,  0.23025587, ...,  0.2832703 ,
#          -2.6137264 , -1.2555118 ],
#         [ 0.19591519,  0.73979264,  1.9176445 , ..., -0.9637335 ,
#           0.7660035 , -1.6753371 ]], dtype=float32),
#  'rewards': array([-1.0263264 , -0.7804776 , -0.16335121, ...,  9.162315  ,
#          9.059013  ,  8.09642   ], dtype=float32),
#  'terminals': array([False, False, False, ..., False, False, False]),
#  'timeouts': array([False, False, False, ..., False, False,  True])}

# %%
import sys
from pathlib import Path
import gym
import d4rl
import numpy as np

PROJECT_ROOT_DIR = Path().absolute().parent
PROJECT_ROOT_DIR

if str(PROJECT_ROOT_DIR.absolute()) not in sys.path:
    sys.path.append(str(PROJECT_ROOT_DIR.absolute()))

from models.sb3_model import PPOWithBCLoss
from utils.sb3_env_wrappers import ScaledObservationWrapper
from rollout import rollout, save_data_to_h5_file
from utils.load_data import load_data, scale_obs, split_data

# %%
RL_EXPERIMENT_NAMES = [
    "iter_1/human_pen_1e7steps_8envs_kl1e-1_loss_1",
    "iter_1/human_pen_1e7steps_8envs_kl1e-1_loss_2",
    "iter_1/human_pen_1e7steps_8envs_kl1e-1_loss_3",
    "iter_1/human_pen_1e7steps_8envs_kl1e-1_loss_4",
    "iter_1/human_pen_1e7steps_8envs_kl1e-1_loss_5",
]
ENV_NAME = "pen-human-v1"
deterministic_sample = False

# %%
origin_env = gym.make(ENV_NAME)
    
obs, acts, infos = load_data(origin_env)
scaled_obs, scaler = scale_obs(obs)

env = ScaledObservationWrapper(env=origin_env, scaler=scaler)
# Out:
# /home/ucav/anaconda3/envs/d4rl0/lib/python3.8/site-packages/gym/spaces/box.py:73: UserWarning: WARN: Box bound precision lowered by casting to float32
#   logger.warn(
# load datafile: 100%|██████████| 8/8 [00:00<00:00, 457.34it/s]

# %%
datasets = []
policy_save_dirs = [PROJECT_ROOT_DIR / "checkpoints" / "rl" / item for item in RL_EXPERIMENT_NAMES]
for policy_save_dir in policy_save_dirs:
    algo_ppo = PPOWithBCLoss.load(str((policy_save_dir / "best_model").absolute()))
    algo_ppo.policy.set_training_mode(False)
    dataset = rollout(
        algo_ppo.policy, 
        env, 
        max_path=1000, 
        num_data=int(1e6 / len(RL_EXPERIMENT_NAMES)), 
        deterministic=deterministic_sample
    )
    datasets.append(dataset)
# Out:
# Finished trajectory. Len=100, Returns=5120.775549. Progress:0/200000
# Finished trajectory. Len=100, Returns=3377.530078. Progress:100/200000
# Finished trajectory. Len=100, Returns=2901.854483. Progress:200/200000
# Finished trajectory. Len=100, Returns=4013.691098. Progress:300/200000
# Finished trajectory. Len=100, Returns=4537.171444. Progress:400/200000
# Finished trajectory. Len=100, Returns=4149.457816. Progress:500/200000
# Finished trajectory. Len=100, Returns=2988.685433. Progress:600/200000
# Finished trajectory. Len=100, Returns=4368.918125. Progress:700/200000
# Finished trajectory. Len=100, Returns=3921.046268. Progress:800/200000
# Finished trajectory. Len=100, Returns=166.178103. Progress:900/200000
# Finished trajectory. Len=100, Returns=4668.051391. Progress:1000/200000
# Finished trajectory. Len=100, Returns=4114.096234. Progress:1100/200000
# Finished trajectory. Len=100, Returns=4322.330695. Progress:1200/200000
# Finished trajectory. Len=100, Returns=5037.298836. Progress:1300/200000
# Finished trajectory. Len=100, Returns=2141.199408. Progress:1400/200000
# Finished trajectory. Len=100, Returns=31.139621. Progress:1500/200000
# Finished trajectory. Len=100, Returns=3843.506466. Progress:1600/200000
# Finished trajectory. Len=100, Returns=2374.301854. Progress:1700/200000
# Finished trajectory. Len=100, Returns=3411.551390. Progress:1800/200000
# Finished trajectory. Len=100, Returns=27.012178. Progress:1900/200000
# Finished trajectory. Len=100, Returns=4449.493760. Progress:2000/200000
# Finished trajectory. Len=100, Returns=3279.459109. Progress:2100/200000
# Finished trajectory. Len=100, Returns=-16.492065. Progress:2200/200000
# Finished trajectory. Len=100, Returns=565.436522. Progress:2300/200000
# Finished trajectory. Len=100, Returns=2930.540726. Progress:2400/200000
# Finished trajectory. Len=100, Returns=684.704867. Progress:2500/200000
# Finished trajectory. Len=100, Returns=2984.120086. Progress:2600/200000
# Finished trajectory. Len=100, Returns=5333.108334. Progress:2700/200000
# Finished trajectory. Len=100, Returns=5168.622558. Progress:2800/200000
# Finished trajectory. Len=100, Returns=4221.305054. Progress:2900/200000
# Finished trajectory. Len=100, Returns=31.479946. Progress:3000/200000
# Finished trajectory. Len=100, Returns=2763.986482. Progress:3100/200000
# Finished trajectory. Len=100, Returns=4529.292915. Progress:3200/200000
# Finished trajectory. Len=100, Returns=40.203954. Progress:3300/200000
# Finished trajectory. Len=100, Returns=4106.005623. Progress:3400/200000
# Finished trajectory. Len=100, Returns=4667.542419. Progress:3500/200000
# Finished trajectory. Len=100, Returns=829.435226. Progress:3600/200000
# Finished trajectory. Len=100, Returns=3202.563555. Progress:3700/200000
# Finished trajectory. Len=100, Returns=4999.340392. Progress:3800/200000
# Finished trajectory. Len=100, Returns=1567.114477. Progress:3900/200000
# Finished trajectory. Len=100, Returns=4409.634728. Progress:4000/200000
# Finished trajectory. Len=100, Returns=5026.090926. Progress:4100/200000
# Finished trajectory. Len=100, Returns=5037.785324. Progress:4200/200000
# Finished trajectory. Len=100, Returns=35.197048. Progress:4300/200000
# Finished trajectory. Len=100, Returns=4587.562861. Progress:4400/200000
# Finished trajectory. Len=100, Returns=2521.196881. Progress:4500/200000
# Finished trajectory. Len=100, Returns=1493.726399. Progress:4600/200000
# Finished trajectory. Len=100, Returns=4830.117554. Progress:4700/200000
# Finished trajectory. Len=100, Returns=3282.304481. Progress:4800/200000
# Finished trajectory. Len=100, Returns=814.343761. Progress:4900/200000
# Finished trajectory. Len=100, Returns=5341.426351. Progress:5000/200000
# Finished trajectory. Len=100, Returns=4926.331645. Progress:5100/200000
# Finished trajectory. Len=100, Returns=4146.295148. Progress:5200/200000
# Finished trajectory. Len=100, Returns=3674.705003. Progress:5300/200000
# Finished trajectory. Len=100, Returns=4615.160540. Progress:5400/200000
# Finished trajectory. Len=100, Returns=1215.771453. Progress:5500/200000
# Finished trajectory. Len=100, Returns=29.262804. Progress:5600/200000
# Finished trajectory. Len=100, Returns=2263.426570. Progress:5700/200000
# Finished trajectory. Len=100, Returns=2435.744735. Progress:5800/200000
# Finished trajectory. Len=100, Returns=2075.581110. Progress:5900/200000
# Finished trajectory. Len=100, Returns=2690.647406. Progress:6000/200000
# Finished trajectory. Len=100, Returns=3979.976450. Progress:6100/200000
# Finished trajectory. Len=100, Returns=4676.004716. Progress:6200/200000
# Finished trajectory. Len=100, Returns=5169.020118. Progress:6300/200000
# Finished trajectory. Len=100, Returns=5271.917701. Progress:6400/200000
# Finished trajectory. Len=100, Returns=3391.581687. Progress:6500/200000
# Finished trajectory. Len=100, Returns=4503.501663. Progress:6600/200000
# Finished trajectory. Len=100, Returns=2848.492606. Progress:6700/200000
# Finished trajectory. Len=100, Returns=3766.592969. Progress:6800/200000
# Finished trajectory. Len=100, Returns=549.331913. Progress:6900/200000
# Finished trajectory. Len=100, Returns=1.712532. Progress:7000/200000
# Finished trajectory. Len=100, Returns=5158.459457. Progress:7100/200000
# Finished trajectory. Len=100, Returns=3810.700585. Progress:7200/200000
# Finished trajectory. Len=100, Returns=3776.135957. Progress:7300/200000
# Finished trajectory. Len=100, Returns=4121.966584. Progress:7400/200000
# Finished trajectory. Len=100, Returns=46.964707. Progress:7500/200000
# Finished trajectory. Len=100, Returns=4074.339170. Progress:7600/200000
# Finished trajectory. Len=100, Returns=3324.329952. Progress:7700/200000
# Finished trajectory. Len=100, Returns=1687.170487. Progress:7800/200000
# Finished trajectory. Len=100, Returns=5271.930602. Progress:7900/200000
# Finished trajectory. Len=100, Returns=4369.675716. Progress:8000/200000
# Finished trajectory. Len=100, Returns=4210.898454. Progress:8100/200000
# Finished trajectory. Len=100, Returns=5088.142905. Progress:8200/200000
# Finished trajectory. Len=100, Returns=4089.575772. Progress:8300/200000
# Finished trajectory. Len=100, Returns=1125.419158. Progress:8400/200000
# Finished trajectory. Len=100, Returns=4890.131790. Progress:8500/200000
# Finished trajectory. Len=100, Returns=4222.445996. Progress:8600/200000
# Finished trajectory. Len=100, Returns=3183.519182. Progress:8700/200000
# Finished trajectory. Len=100, Returns=3183.025938. Progress:8800/200000
# Finished trajectory. Len=100, Returns=663.857868. Progress:8900/200000
# Finished trajectory. Len=100, Returns=3715.333037. Progress:9000/200000
# Finished trajectory. Len=100, Returns=3665.954655. Progress:9100/200000
# Finished trajectory. Len=100, Returns=684.660166. Progress:9200/200000
# Finished trajectory. Len=100, Returns=1466.739263. Progress:9300/200000
# Finished trajectory. Len=100, Returns=4.395234. Progress:9400/200000
# Finished trajectory. Len=100, Returns=1059.128250. Progress:9500/200000
# Finished trajectory. Len=100, Returns=481.558071. Progress:9600/200000
# Finished trajectory. Len=100, Returns=4004.111188. Progress:9700/200000
# Finished trajectory. Len=100, Returns=4802.356593. Progress:9800/200000
# Finished trajectory. Len=100, Returns=62.321734. Progress:9900/200000
# Finished trajectory. Len=100, Returns=461.148508. Progress:10000/200000
# Finished trajectory. Len=100, Returns=4728.669740. Progress:10100/200000
# Finished trajectory. Len=100, Returns=1275.540232. Progress:10200/200000
# Finished trajectory. Len=100, Returns=3350.988632. Progress:10300/200000
# Finished trajectory. Len=100, Returns=43.965377. Progress:10400/200000
# Finished trajectory. Len=100, Returns=55.394658. Progress:10500/200000
# Finished trajectory. Len=100, Returns=5392.582038. Progress:10600/200000
# Finished trajectory. Len=100, Returns=34.000406. Progress:10700/200000
# Finished trajectory. Len=100, Returns=2426.829004. Progress:10800/200000
# Finished trajectory. Len=100, Returns=5159.186827. Progress:10900/200000
# Finished trajectory. Len=98, Returns=2022.894264. Progress:11000/200000
# Finished trajectory. Len=100, Returns=696.569685. Progress:11098/200000
# Finished trajectory. Len=100, Returns=5331.937576. Progress:11198/200000
# Finished trajectory. Len=100, Returns=3606.303639. Progress:11298/200000
# Finished trajectory. Len=100, Returns=904.089770. Progress:11398/200000
# Finished trajectory. Len=100, Returns=5391.239527. Progress:11498/200000
# Finished trajectory. Len=100, Returns=1674.403286. Progress:11598/200000
# Finished trajectory. Len=100, Returns=11.637282. Progress:11698/200000
# Finished trajectory. Len=100, Returns=3913.970847. Progress:11798/200000
# Finished trajectory. Len=100, Returns=3076.633169. Progress:11898/200000
# Finished trajectory. Len=100, Returns=1739.823274. Progress:11998/200000
# Finished trajectory. Len=100, Returns=3932.232520. Progress:12098/200000
# Finished trajectory. Len=100, Returns=2420.995628. Progress:12198/200000
# Finished trajectory. Len=100, Returns=46.477065. Progress:12298/200000
# Finished trajectory. Len=100, Returns=3872.124371. Progress:12398/200000
# Finished trajectory. Len=100, Returns=1555.849435. Progress:12498/200000
# Finished trajectory. Len=100, Returns=1130.082959. Progress:12598/200000
# Finished trajectory. Len=100, Returns=2866.856489. Progress:12698/200000
# Finished trajectory. Len=100, Returns=2405.639306. Progress:12798/200000
# Finished trajectory. Len=100, Returns=2476.570851. Progress:12898/200000
# Finished trajectory. Len=100, Returns=4537.612564. Progress:12998/200000
# Finished trajectory. Len=100, Returns=4138.977729. Progress:13098/200000
# Finished trajectory. Len=100, Returns=5272.006521. Progress:13198/200000
# Finished trajectory. Len=100, Returns=5511.777285. Progress:13298/200000
# Finished trajectory. Len=100, Returns=3999.114323. Progress:13398/200000
# Finished trajectory. Len=100, Returns=635.787800. Progress:13498/200000
# Finished trajectory. Len=100, Returns=133.651905. Progress:13598/200000
# Finished trajectory. Len=100, Returns=5391.810469. Progress:13698/200000
# Finished trajectory. Len=100, Returns=2842.039926. Progress:13798/200000
# Finished trajectory. Len=100, Returns=5279.195120. Progress:13898/200000
# Finished trajectory. Len=100, Returns=4606.335540. Progress:13998/200000
# Finished trajectory. Len=100, Returns=2604.378516. Progress:14098/200000
# Finished trajectory. Len=100, Returns=61.504798. Progress:14198/200000
# Finished trajectory. Len=100, Returns=5218.826897. Progress:14298/200000
# Finished trajectory. Len=100, Returns=4965.981449. Progress:14398/200000
# Finished trajectory. Len=100, Returns=765.358082. Progress:14498/200000
# Finished trajectory. Len=100, Returns=655.922504. Progress:14598/200000
# Finished trajectory. Len=100, Returns=4159.726667. Progress:14698/200000
# Finished trajectory. Len=100, Returns=3932.936816. Progress:14798/200000
# Finished trajectory. Len=100, Returns=2697.873327. Progress:14898/200000
# Finished trajectory. Len=100, Returns=2554.811926. Progress:14998/200000
# Finished trajectory. Len=100, Returns=4555.104080. Progress:15098/200000
# Finished trajectory. Len=100, Returns=2664.444256. Progress:15198/200000
# Finished trajectory. Len=100, Returns=1914.918164. Progress:15298/200000
# Finished trajectory. Len=100, Returns=2312.809709. Progress:15398/200000
# Finished trajectory. Len=100, Returns=3576.017346. Progress:15498/200000
# Finished trajectory. Len=100, Returns=752.697842. Progress:15598/200000
# Finished trajectory. Len=100, Returns=4089.379462. Progress:15698/200000
# Finished trajectory. Len=100, Returns=5222.313135. Progress:15798/200000
# Finished trajectory. Len=100, Returns=3661.394370. Progress:15898/200000
# Finished trajectory. Len=100, Returns=4199.775922. Progress:15998/200000
# Finished trajectory. Len=100, Returns=695.097905. Progress:16098/200000
# Finished trajectory. Len=100, Returns=4295.501091. Progress:16198/200000
# Finished trajectory. Len=100, Returns=1977.147988. Progress:16298/200000
# Finished trajectory. Len=100, Returns=5271.561792. Progress:16398/200000
# Finished trajectory. Len=100, Returns=3806.462021. Progress:16498/200000
# Finished trajectory. Len=100, Returns=5393.042659. Progress:16598/200000
# Finished trajectory. Len=100, Returns=5270.904499. Progress:16698/200000
# Finished trajectory. Len=100, Returns=4597.837935. Progress:16798/200000
# Finished trajectory. Len=100, Returns=5221.448087. Progress:16898/200000
# Finished trajectory. Len=100, Returns=5271.630324. Progress:16998/200000
# Finished trajectory. Len=100, Returns=15.080369. Progress:17098/200000
# Finished trajectory. Len=100, Returns=-12.471694. Progress:17198/200000
# Finished trajectory. Len=100, Returns=23.921395. Progress:17298/200000
# Finished trajectory. Len=100, Returns=3450.841801. Progress:17398/200000
# Finished trajectory. Len=100, Returns=4358.690224. Progress:17498/200000
# Finished trajectory. Len=100, Returns=3797.365057. Progress:17598/200000
# Finished trajectory. Len=100, Returns=4534.749193. Progress:17698/200000
# Finished trajectory. Len=100, Returns=43.268817. Progress:17798/200000
# Finished trajectory. Len=100, Returns=-9.987393. Progress:17898/200000
# Finished trajectory. Len=100, Returns=5026.040356. Progress:17998/200000
# Finished trajectory. Len=100, Returns=1131.758370. Progress:18098/200000
# Finished trajectory. Len=100, Returns=5025.302614. Progress:18198/200000
# Finished trajectory. Len=100, Returns=657.847924. Progress:18298/200000
# Finished trajectory. Len=100, Returns=2224.471502. Progress:18398/200000
# Finished trajectory. Len=100, Returns=2460.586475. Progress:18498/200000
# Finished trajectory. Len=100, Returns=5332.792501. Progress:18598/200000
# Finished trajectory. Len=100, Returns=103.440358. Progress:18698/200000
# Finished trajectory. Len=100, Returns=4013.051563. Progress:18798/200000
# Finished trajectory. Len=100, Returns=2655.850388. Progress:18898/200000
# Finished trajectory. Len=100, Returns=1360.492206. Progress:18998/200000
# Finished trajectory. Len=100, Returns=2827.979546. Progress:19098/200000
# Finished trajectory. Len=100, Returns=1822.867068. Progress:19198/200000
# Finished trajectory. Len=100, Returns=3270.877436. Progress:19298/200000
# Finished trajectory. Len=100, Returns=1732.600677. Progress:19398/200000
# Finished trajectory. Len=100, Returns=4000.903228. Progress:19498/200000
# Finished trajectory. Len=100, Returns=4245.781252. Progress:19598/200000
# Finished trajectory. Len=100, Returns=722.691478. Progress:19698/200000
# Finished trajectory. Len=100, Returns=3477.593633. Progress:19798/200000
# Finished trajectory. Len=100, Returns=4056.634894. Progress:19898/200000
# Finished trajectory. Len=100, Returns=3.603851. Progress:19998/200000
# Finished trajectory. Len=100, Returns=4697.242752. Progress:20098/200000
# Finished trajectory. Len=100, Returns=5291.198471. Progress:20198/200000
# Finished trajectory. Len=100, Returns=3021.376090. Progress:20298/200000
# Finished trajectory. Len=100, Returns=36.248305. Progress:20398/200000
# Finished trajectory. Len=100, Returns=3094.909721. Progress:20498/200000
# Finished trajectory. Len=100, Returns=572.316559. Progress:20598/200000
# Finished trajectory. Len=100, Returns=5280.863689. Progress:20698/200000
# Finished trajectory. Len=100, Returns=4389.081680. Progress:20798/200000
# Finished trajectory. Len=100, Returns=22.735072. Progress:20898/200000
# Finished trajectory. Len=100, Returns=1574.468873. Progress:20998/200000
# Finished trajectory. Len=100, Returns=4657.083410. Progress:21098/200000
# Finished trajectory. Len=100, Returns=19.751472. Progress:21198/200000
# Finished trajectory. Len=100, Returns=2800.699268. Progress:21298/200000
# Finished trajectory. Len=100, Returns=5149.005245. Progress:21398/200000
# Finished trajectory. Len=100, Returns=311.704143. Progress:21498/200000
# Finished trajectory. Len=100, Returns=681.177337. Progress:21598/200000
# Finished trajectory. Len=100, Returns=5341.820290. Progress:21698/200000
# Finished trajectory. Len=100, Returns=2573.781503. Progress:21798/200000
# Finished trajectory. Len=100, Returns=3987.025585. Progress:21898/200000
# Finished trajectory. Len=100, Returns=777.044712. Progress:21998/200000
# Finished trajectory. Len=100, Returns=2713.602019. Progress:22098/200000
# Finished trajectory. Len=100, Returns=2345.722096. Progress:22198/200000
# Finished trajectory. Len=100, Returns=2281.690913. Progress:22298/200000
# Finished trajectory. Len=100, Returns=4246.129531. Progress:22398/200000
# Finished trajectory. Len=100, Returns=3018.442206. Progress:22498/200000
# Finished trajectory. Len=100, Returns=4955.952172. Progress:22598/200000
# Finished trajectory. Len=100, Returns=5400.547316. Progress:22698/200000
# Finished trajectory. Len=100, Returns=2483.578306. Progress:22798/200000
# Finished trajectory. Len=100, Returns=2288.439190. Progress:22898/200000
# Finished trajectory. Len=100, Returns=5037.085849. Progress:22998/200000
# Finished trajectory. Len=100, Returns=3572.576453. Progress:23098/200000
# Finished trajectory. Len=100, Returns=2901.439671. Progress:23198/200000
# Finished trajectory. Len=100, Returns=4675.733903. Progress:23298/200000
# Finished trajectory. Len=100, Returns=5014.443520. Progress:23398/200000
# Finished trajectory. Len=100, Returns=4129.183649. Progress:23498/200000
# Finished trajectory. Len=100, Returns=3877.551815. Progress:23598/200000
# Finished trajectory. Len=100, Returns=3735.966477. Progress:23698/200000
# Finished trajectory. Len=100, Returns=2414.477145. Progress:23798/200000
# Finished trajectory. Len=100, Returns=5037.061131. Progress:23898/200000
# Finished trajectory. Len=100, Returns=5452.816077. Progress:23998/200000
# Finished trajectory. Len=100, Returns=65.001519. Progress:24098/200000
# Finished trajectory. Len=100, Returns=4054.242024. Progress:24198/200000
# Finished trajectory. Len=100, Returns=207.299795. Progress:24298/200000
# Finished trajectory. Len=100, Returns=4614.853077. Progress:24398/200000
# Finished trajectory. Len=100, Returns=3658.059485. Progress:24498/200000
# Finished trajectory. Len=100, Returns=4656.573017. Progress:24598/200000
# Finished trajectory. Len=100, Returns=5341.650655. Progress:24698/200000
# Finished trajectory. Len=100, Returns=1817.075841. Progress:24798/200000
# Finished trajectory. Len=100, Returns=5088.857601. Progress:24898/200000
# Finished trajectory. Len=100, Returns=5332.487963. Progress:24998/200000
# Finished trajectory. Len=100, Returns=3219.462630. Progress:25098/200000
# Finished trajectory. Len=100, Returns=542.997201. Progress:25198/200000
# Finished trajectory. Len=100, Returns=765.361779. Progress:25298/200000
# Finished trajectory. Len=100, Returns=3413.450762. Progress:25398/200000
# Finished trajectory. Len=100, Returns=1564.437938. Progress:25498/200000
# Finished trajectory. Len=100, Returns=123.915841. Progress:25598/200000
# Finished trajectory. Len=100, Returns=5453.551534. Progress:25698/200000
# Finished trajectory. Len=100, Returns=254.853443. Progress:25798/200000
# Finished trajectory. Len=100, Returns=4111.761527. Progress:25898/200000
# Finished trajectory. Len=100, Returns=1356.863167. Progress:25998/200000
# Finished trajectory. Len=100, Returns=380.464208. Progress:26098/200000
# Finished trajectory. Len=100, Returns=4748.298557. Progress:26198/200000
# Finished trajectory. Len=100, Returns=3064.204382. Progress:26298/200000
# Finished trajectory. Len=100, Returns=753.461098. Progress:26398/200000
# Finished trajectory. Len=100, Returns=3250.843728. Progress:26498/200000
# Finished trajectory. Len=100, Returns=2565.108180. Progress:26598/200000
# Finished trajectory. Len=100, Returns=3809.133118. Progress:26698/200000
# Finished trajectory. Len=100, Returns=5343.154778. Progress:26798/200000
# Finished trajectory. Len=100, Returns=4808.718684. Progress:26898/200000
# Finished trajectory. Len=100, Returns=4951.495165. Progress:26998/200000
# Finished trajectory. Len=100, Returns=4951.385492. Progress:27098/200000
# Finished trajectory. Len=100, Returns=3742.066005. Progress:27198/200000
# Finished trajectory. Len=100, Returns=-18.143631. Progress:27298/200000
# Finished trajectory. Len=100, Returns=2388.195066. Progress:27398/200000
# Finished trajectory. Len=100, Returns=4244.581850. Progress:27498/200000
# Finished trajectory. Len=100, Returns=2062.250874. Progress:27598/200000
# Finished trajectory. Len=100, Returns=35.993000. Progress:27698/200000
# Finished trajectory. Len=100, Returns=265.652275. Progress:27798/200000
# Finished trajectory. Len=100, Returns=5279.812623. Progress:27898/200000
# Finished trajectory. Len=100, Returns=4148.551682. Progress:27998/200000
# Finished trajectory. Len=100, Returns=3956.846831. Progress:28098/200000
# Finished trajectory. Len=100, Returns=36.980678. Progress:28198/200000
# Finished trajectory. Len=100, Returns=3.683797. Progress:28298/200000
# Finished trajectory. Len=100, Returns=4953.861996. Progress:28398/200000
# Finished trajectory. Len=100, Returns=4979.848595. Progress:28498/200000
# Finished trajectory. Len=100, Returns=48.143132. Progress:28598/200000
# Finished trajectory. Len=100, Returns=3818.671688. Progress:28698/200000
# Finished trajectory. Len=100, Returns=3156.819519. Progress:28798/200000
# Finished trajectory. Len=100, Returns=4756.054722. Progress:28898/200000
# Finished trajectory. Len=100, Returns=3084.496938. Progress:28998/200000
# Finished trajectory. Len=100, Returns=5230.076122. Progress:29098/200000
# Finished trajectory. Len=100, Returns=5149.822918. Progress:29198/200000
# Finished trajectory. Len=100, Returns=5260.996399. Progress:29298/200000
# Finished trajectory. Len=100, Returns=48.568576. Progress:29398/200000
# Finished trajectory. Len=100, Returns=3337.518052. Progress:29498/200000
# Finished trajectory. Len=100, Returns=-3.422112. Progress:29598/200000
# Finished trajectory. Len=100, Returns=3870.364992. Progress:29698/200000
# Finished trajectory. Len=100, Returns=1013.327897. Progress:29798/200000
# Finished trajectory. Len=100, Returns=3055.066142. Progress:29898/200000
# Finished trajectory. Len=100, Returns=4001.075845. Progress:29998/200000
# Finished trajectory. Len=100, Returns=3533.232356. Progress:30098/200000
# Finished trajectory. Len=100, Returns=5451.971637. Progress:30198/200000
# Finished trajectory. Len=100, Returns=21.471127. Progress:30298/200000
# Finished trajectory. Len=100, Returns=2744.269183. Progress:30398/200000
# Finished trajectory. Len=100, Returns=3315.287733. Progress:30498/200000
# Finished trajectory. Len=100, Returns=14.493796. Progress:30598/200000
# Finished trajectory. Len=100, Returns=3854.696304. Progress:30698/200000
# Finished trajectory. Len=100, Returns=4657.866217. Progress:30798/200000
# Finished trajectory. Len=100, Returns=4266.799001. Progress:30898/200000
# Finished trajectory. Len=100, Returns=324.348474. Progress:30998/200000
# Finished trajectory. Len=100, Returns=3685.908123. Progress:31098/200000
# Finished trajectory. Len=100, Returns=1101.430942. Progress:31198/200000
# Finished trajectory. Len=100, Returns=3535.068825. Progress:31298/200000
# Finished trajectory. Len=100, Returns=3634.766360. Progress:31398/200000
# Finished trajectory. Len=100, Returns=5028.835021. Progress:31498/200000
# Finished trajectory. Len=100, Returns=3686.965553. Progress:31598/200000
# Finished trajectory. Len=100, Returns=43.486605. Progress:31698/200000
# Finished trajectory. Len=100, Returns=4016.186724. Progress:31798/200000
# Finished trajectory. Len=100, Returns=12.661253. Progress:31898/200000
# Finished trajectory. Len=100, Returns=4251.016933. Progress:31998/200000
# Finished trajectory. Len=100, Returns=3067.923759. Progress:32098/200000
# Finished trajectory. Len=100, Returns=5291.127291. Progress:32198/200000
# Finished trajectory. Len=100, Returns=3035.112186. Progress:32298/200000
# Finished trajectory. Len=100, Returns=5452.928623. Progress:32398/200000
# Finished trajectory. Len=100, Returns=3634.482949. Progress:32498/200000
# Finished trajectory. Len=100, Returns=1814.028499. Progress:32598/200000
# Finished trajectory. Len=100, Returns=3984.454431. Progress:32698/200000
# Finished trajectory. Len=100, Returns=148.432081. Progress:32798/200000
# Finished trajectory. Len=100, Returns=4123.377622. Progress:32898/200000
# Finished trajectory. Len=100, Returns=3892.236856. Progress:32998/200000
# Finished trajectory. Len=100, Returns=4626.209240. Progress:33098/200000
# Finished trajectory. Len=100, Returns=2990.745181. Progress:33198/200000
# Finished trajectory. Len=100, Returns=4687.390138. Progress:33298/200000
# Finished trajectory. Len=100, Returns=4659.972420. Progress:33398/200000
# Finished trajectory. Len=100, Returns=5027.325783. Progress:33498/200000
# Finished trajectory. Len=100, Returns=839.662373. Progress:33598/200000
# Finished trajectory. Len=100, Returns=5271.799865. Progress:33698/200000
# Finished trajectory. Len=100, Returns=4069.787284. Progress:33798/200000
# Finished trajectory. Len=91, Returns=1659.147726. Progress:33898/200000
# Finished trajectory. Len=100, Returns=50.997283. Progress:33989/200000
# Finished trajectory. Len=100, Returns=2590.665357. Progress:34089/200000
# Finished trajectory. Len=100, Returns=5099.952865. Progress:34189/200000
# Finished trajectory. Len=100, Returns=4965.143861. Progress:34289/200000
# Finished trajectory. Len=100, Returns=5221.374283. Progress:34389/200000
# Finished trajectory. Len=100, Returns=4756.530946. Progress:34489/200000
# Finished trajectory. Len=100, Returns=29.851779. Progress:34589/200000
# Finished trajectory. Len=100, Returns=693.658017. Progress:34689/200000
# Finished trajectory. Len=100, Returns=88.717924. Progress:34789/200000
# Finished trajectory. Len=100, Returns=4123.439840. Progress:34889/200000
# Finished trajectory. Len=100, Returns=3123.147674. Progress:34989/200000
# Finished trajectory. Len=100, Returns=5340.087997. Progress:35089/200000
# Finished trajectory. Len=100, Returns=854.128651. Progress:35189/200000
# Finished trajectory. Len=100, Returns=5049.109948. Progress:35289/200000
# Finished trajectory. Len=100, Returns=3983.438191. Progress:35389/200000
# Finished trajectory. Len=100, Returns=5160.630046. Progress:35489/200000
# Finished trajectory. Len=100, Returns=1254.843974. Progress:35589/200000
# Finished trajectory. Len=100, Returns=19.370525. Progress:35689/200000
# Finished trajectory. Len=100, Returns=4001.972248. Progress:35789/200000
# Finished trajectory. Len=100, Returns=5290.404898. Progress:35889/200000
# Finished trajectory. Len=100, Returns=5131.110831. Progress:35989/200000
# Finished trajectory. Len=100, Returns=4599.891680. Progress:36089/200000
# Finished trajectory. Len=100, Returns=1700.926067. Progress:36189/200000
# Finished trajectory. Len=100, Returns=-57.858536. Progress:36289/200000
# Finished trajectory. Len=100, Returns=5220.800803. Progress:36389/200000
# Finished trajectory. Len=100, Returns=27.698400. Progress:36489/200000
# Finished trajectory. Len=100, Returns=105.812959. Progress:36589/200000
# Finished trajectory. Len=100, Returns=3865.121253. Progress:36689/200000
# Finished trajectory. Len=100, Returns=5402.080725. Progress:36789/200000
# Finished trajectory. Len=100, Returns=3749.723669. Progress:36889/200000
# Finished trajectory. Len=100, Returns=4036.745757. Progress:36989/200000
# Finished trajectory. Len=100, Returns=4522.639966. Progress:37089/200000
# Finished trajectory. Len=100, Returns=632.627059. Progress:37189/200000
# Finished trajectory. Len=100, Returns=3943.124523. Progress:37289/200000
# Finished trajectory. Len=100, Returns=652.081367. Progress:37389/200000
# Finished trajectory. Len=100, Returns=1786.727214. Progress:37489/200000
# Finished trajectory. Len=100, Returns=3209.174169. Progress:37589/200000
# Finished trajectory. Len=100, Returns=5027.064873. Progress:37689/200000
# Finished trajectory. Len=100, Returns=5280.209617. Progress:37789/200000
# Finished trajectory. Len=100, Returns=4890.986072. Progress:37889/200000
# Finished trajectory. Len=100, Returns=2076.068107. Progress:37989/200000
# Finished trajectory. Len=100, Returns=33.011874. Progress:38089/200000
# Finished trajectory. Len=100, Returns=4905.101027. Progress:38189/200000
# Finished trajectory. Len=100, Returns=3290.252654. Progress:38289/200000
# Finished trajectory. Len=100, Returns=2742.152159. Progress:38389/200000
# Finished trajectory. Len=100, Returns=17.923117. Progress:38489/200000
# Finished trajectory. Len=100, Returns=3350.259262. Progress:38589/200000
# Finished trajectory. Len=100, Returns=5059.577577. Progress:38689/200000
# Finished trajectory. Len=100, Returns=4271.570997. Progress:38789/200000
# Finished trajectory. Len=100, Returns=5452.049360. Progress:38889/200000
# Finished trajectory. Len=100, Returns=5160.580083. Progress:38989/200000
# Finished trajectory. Len=100, Returns=3537.392160. Progress:39089/200000
# Finished trajectory. Len=100, Returns=143.901577. Progress:39189/200000
# Finished trajectory. Len=100, Returns=4686.345294. Progress:39289/200000
# Finished trajectory. Len=100, Returns=1337.688922. Progress:39389/200000
# Finished trajectory. Len=100, Returns=4123.768044. Progress:39489/200000
# Finished trajectory. Len=100, Returns=3379.502031. Progress:39589/200000
# Finished trajectory. Len=100, Returns=486.452543. Progress:39689/200000
# Finished trajectory. Len=100, Returns=3012.167615. Progress:39789/200000
# Finished trajectory. Len=100, Returns=5209.862121. Progress:39889/200000
# Finished trajectory. Len=100, Returns=3474.039582. Progress:39989/200000
# Finished trajectory. Len=100, Returns=4901.444376. Progress:40089/200000
# Finished trajectory. Len=100, Returns=3376.328748. Progress:40189/200000
# Finished trajectory. Len=100, Returns=355.160676. Progress:40289/200000
# Finished trajectory. Len=100, Returns=5322.083397. Progress:40389/200000
# Finished trajectory. Len=100, Returns=4975.047255. Progress:40489/200000
# Finished trajectory. Len=100, Returns=2377.162559. Progress:40589/200000
# Finished trajectory. Len=100, Returns=5209.948588. Progress:40689/200000
# Finished trajectory. Len=100, Returns=724.001561. Progress:40789/200000
# Finished trajectory. Len=100, Returns=4802.939435. Progress:40889/200000
# Finished trajectory. Len=100, Returns=1795.792372. Progress:40989/200000
# Finished trajectory. Len=100, Returns=4988.624885. Progress:41089/200000
# Finished trajectory. Len=100, Returns=3197.156047. Progress:41189/200000
# Finished trajectory. Len=100, Returns=47.880980. Progress:41289/200000
# Finished trajectory. Len=100, Returns=2.122443. Progress:41389/200000
# Finished trajectory. Len=100, Returns=4908.758402. Progress:41489/200000
# Finished trajectory. Len=100, Returns=3389.908779. Progress:41589/200000
# Finished trajectory. Len=100, Returns=735.548857. Progress:41689/200000
# Finished trajectory. Len=100, Returns=-1.620849. Progress:41789/200000
# Finished trajectory. Len=100, Returns=3937.956778. Progress:41889/200000
# Finished trajectory. Len=100, Returns=4128.753557. Progress:41989/200000
# Finished trajectory. Len=100, Returns=4183.921948. Progress:42089/200000
# Finished trajectory. Len=100, Returns=4641.581841. Progress:42189/200000
# Finished trajectory. Len=100, Returns=2088.933829. Progress:42289/200000
# Finished trajectory. Len=100, Returns=35.601420. Progress:42389/200000
# Finished trajectory. Len=100, Returns=230.013652. Progress:42489/200000
# Finished trajectory. Len=100, Returns=743.108207. Progress:42589/200000
# Finished trajectory. Len=100, Returns=685.399858. Progress:42689/200000
# Finished trajectory. Len=100, Returns=3809.632325. Progress:42789/200000
# Finished trajectory. Len=100, Returns=1367.808192. Progress:42889/200000
# Finished trajectory. Len=100, Returns=3355.771063. Progress:42989/200000
# Finished trajectory. Len=100, Returns=598.543751. Progress:43089/200000
# Finished trajectory. Len=100, Returns=5139.205857. Progress:43189/200000
# Finished trajectory. Len=100, Returns=5281.255230. Progress:43289/200000
# Finished trajectory. Len=100, Returns=4023.993583. Progress:43389/200000
# Finished trajectory. Len=100, Returns=2664.302368. Progress:43489/200000
# Finished trajectory. Len=100, Returns=5100.127930. Progress:43589/200000
# Finished trajectory. Len=100, Returns=3860.641255. Progress:43689/200000
# Finished trajectory. Len=100, Returns=3766.248915. Progress:43789/200000
# Finished trajectory. Len=100, Returns=3956.112655. Progress:43889/200000
# Finished trajectory. Len=100, Returns=685.632794. Progress:43989/200000
# Finished trajectory. Len=100, Returns=5332.722408. Progress:44089/200000
# Finished trajectory. Len=100, Returns=5342.614452. Progress:44189/200000
# Finished trajectory. Len=100, Returns=4976.533244. Progress:44289/200000
# Finished trajectory. Len=100, Returns=3589.763789. Progress:44389/200000
# Finished trajectory. Len=100, Returns=5150.636880. Progress:44489/200000
# Finished trajectory. Len=100, Returns=3113.929949. Progress:44589/200000
# Finished trajectory. Len=100, Returns=5209.683982. Progress:44689/200000
# Finished trajectory. Len=100, Returns=4463.839128. Progress:44789/200000
# Finished trajectory. Len=100, Returns=26.264312. Progress:44889/200000
# Finished trajectory. Len=100, Returns=1957.450951. Progress:44989/200000
# Finished trajectory. Len=100, Returns=3863.868937. Progress:45089/200000
# Finished trajectory. Len=100, Returns=4061.303499. Progress:45189/200000
# Finished trajectory. Len=100, Returns=2821.356010. Progress:45289/200000
# Finished trajectory. Len=90, Returns=18.288926. Progress:45389/200000
# Finished trajectory. Len=100, Returns=3621.093176. Progress:45479/200000
# Finished trajectory. Len=100, Returns=15.595305. Progress:45579/200000
# Finished trajectory. Len=100, Returns=1575.442708. Progress:45679/200000
# Finished trajectory. Len=100, Returns=4665.308646. Progress:45779/200000
# Finished trajectory. Len=100, Returns=3688.027115. Progress:45879/200000
# Finished trajectory. Len=100, Returns=873.377751. Progress:45979/200000
# Finished trajectory. Len=100, Returns=5221.885556. Progress:46079/200000
# Finished trajectory. Len=100, Returns=5026.694958. Progress:46179/200000
# Finished trajectory. Len=100, Returns=3837.310843. Progress:46279/200000
# Finished trajectory. Len=100, Returns=2734.467873. Progress:46379/200000
# Finished trajectory. Len=100, Returns=4670.934293. Progress:46479/200000
# Finished trajectory. Len=100, Returns=4304.590465. Progress:46579/200000
# Finished trajectory. Len=100, Returns=5026.883171. Progress:46679/200000
# Finished trajectory. Len=100, Returns=3693.186611. Progress:46779/200000
# Finished trajectory. Len=100, Returns=1019.540150. Progress:46879/200000
# Finished trajectory. Len=100, Returns=4399.482473. Progress:46979/200000
# Finished trajectory. Len=100, Returns=734.699044. Progress:47079/200000
# Finished trajectory. Len=100, Returns=910.161499. Progress:47179/200000
# Finished trajectory. Len=100, Returns=50.717694. Progress:47279/200000
# Finished trajectory. Len=100, Returns=14.197984. Progress:47379/200000
# Finished trajectory. Len=100, Returns=5169.921740. Progress:47479/200000
# Finished trajectory. Len=100, Returns=4443.194443. Progress:47579/200000
# Finished trajectory. Len=100, Returns=4049.787307. Progress:47679/200000
# Finished trajectory. Len=100, Returns=4981.308908. Progress:47779/200000
# Finished trajectory. Len=100, Returns=3891.452175. Progress:47879/200000
# Finished trajectory. Len=100, Returns=3136.137122. Progress:47979/200000
# Finished trajectory. Len=100, Returns=2114.302373. Progress:48079/200000
# Finished trajectory. Len=100, Returns=3531.586547. Progress:48179/200000
# Finished trajectory. Len=100, Returns=837.232582. Progress:48279/200000
# Finished trajectory. Len=100, Returns=342.938223. Progress:48379/200000
# Finished trajectory. Len=100, Returns=4898.061618. Progress:48479/200000
# Finished trajectory. Len=100, Returns=5089.918667. Progress:48579/200000
# Finished trajectory. Len=100, Returns=36.001048. Progress:48679/200000
# Finished trajectory. Len=100, Returns=3609.944639. Progress:48779/200000
# Finished trajectory. Len=100, Returns=3846.671954. Progress:48879/200000
# Finished trajectory. Len=100, Returns=3973.444670. Progress:48979/200000
# Finished trajectory. Len=100, Returns=5087.671136. Progress:49079/200000
# Finished trajectory. Len=100, Returns=5150.427595. Progress:49179/200000
# Finished trajectory. Len=100, Returns=278.660473. Progress:49279/200000
# Finished trajectory. Len=100, Returns=117.010776. Progress:49379/200000
# Finished trajectory. Len=100, Returns=4563.886475. Progress:49479/200000
# Finished trajectory. Len=100, Returns=4856.624116. Progress:49579/200000
# Finished trajectory. Len=100, Returns=3693.738140. Progress:49679/200000
# Finished trajectory. Len=100, Returns=4839.515747. Progress:49779/200000
# Finished trajectory. Len=100, Returns=2507.747602. Progress:49879/200000
# Finished trajectory. Len=100, Returns=40.336012. Progress:49979/200000
# Finished trajectory. Len=100, Returns=4503.742561. Progress:50079/200000
# Finished trajectory. Len=100, Returns=3311.206670. Progress:50179/200000
# Finished trajectory. Len=100, Returns=583.528680. Progress:50279/200000
# Finished trajectory. Len=100, Returns=2767.268660. Progress:50379/200000
# Finished trajectory. Len=100, Returns=4869.345018. Progress:50479/200000
# Finished trajectory. Len=100, Returns=1803.597809. Progress:50579/200000
# Finished trajectory. Len=100, Returns=2689.994996. Progress:50679/200000
# Finished trajectory. Len=100, Returns=5088.042211. Progress:50779/200000
# Finished trajectory. Len=100, Returns=252.540404. Progress:50879/200000
# Finished trajectory. Len=100, Returns=559.139943. Progress:50979/200000
# Finished trajectory. Len=100, Returns=5031.585815. Progress:51079/200000
# Finished trajectory. Len=100, Returns=5149.260533. Progress:51179/200000
# Finished trajectory. Len=100, Returns=2600.648809. Progress:51279/200000
# Finished trajectory. Len=100, Returns=261.953978. Progress:51379/200000
# Finished trajectory. Len=100, Returns=1887.735492. Progress:51479/200000
# Finished trajectory. Len=100, Returns=4676.503429. Progress:51579/200000
# Finished trajectory. Len=100, Returns=-36.020114. Progress:51679/200000
# Finished trajectory. Len=100, Returns=5212.099847. Progress:51779/200000
# Finished trajectory. Len=100, Returns=2104.704101. Progress:51879/200000
# Finished trajectory. Len=100, Returns=1753.562895. Progress:51979/200000
# Finished trajectory. Len=100, Returns=4153.836177. Progress:52079/200000
# Finished trajectory. Len=100, Returns=5210.557740. Progress:52179/200000
# Finished trajectory. Len=100, Returns=2850.058304. Progress:52279/200000
# Finished trajectory. Len=100, Returns=788.916361. Progress:52379/200000
# Finished trajectory. Len=100, Returns=3557.985132. Progress:52479/200000
# Finished trajectory. Len=100, Returns=4826.516231. Progress:52579/200000
# Finished trajectory. Len=100, Returns=1.085254. Progress:52679/200000
# Finished trajectory. Len=100, Returns=5138.803552. Progress:52779/200000
# Finished trajectory. Len=100, Returns=50.948281. Progress:52879/200000
# Finished trajectory. Len=100, Returns=46.430769. Progress:52979/200000
# Finished trajectory. Len=100, Returns=3156.956093. Progress:53079/200000
# Finished trajectory. Len=100, Returns=4908.953719. Progress:53179/200000
# Finished trajectory. Len=100, Returns=5282.895583. Progress:53279/200000
# Finished trajectory. Len=100, Returns=3302.788421. Progress:53379/200000
# Finished trajectory. Len=100, Returns=5453.592528. Progress:53479/200000
# Finished trajectory. Len=100, Returns=3988.711424. Progress:53579/200000
# Finished trajectory. Len=100, Returns=819.708686. Progress:53679/200000
# Finished trajectory. Len=100, Returns=3038.005050. Progress:53779/200000
# Finished trajectory. Len=100, Returns=4186.866909. Progress:53879/200000
# Finished trajectory. Len=100, Returns=5290.538266. Progress:53979/200000
# Finished trajectory. Len=100, Returns=53.195223. Progress:54079/200000
# Finished trajectory. Len=100, Returns=5100.145718. Progress:54179/200000
# Finished trajectory. Len=100, Returns=5210.629634. Progress:54279/200000
# Finished trajectory. Len=100, Returns=1269.926188. Progress:54379/200000
# Finished trajectory. Len=100, Returns=4210.440271. Progress:54479/200000
# Finished trajectory. Len=100, Returns=777.411062. Progress:54579/200000
# Finished trajectory. Len=100, Returns=4000.759823. Progress:54679/200000
# Finished trajectory. Len=100, Returns=4717.514140. Progress:54779/200000
# Finished trajectory. Len=100, Returns=3999.605021. Progress:54879/200000
# Finished trajectory. Len=100, Returns=3860.516624. Progress:54979/200000
# Finished trajectory. Len=100, Returns=5511.220125. Progress:55079/200000
# Finished trajectory. Len=100, Returns=3975.943878. Progress:55179/200000
# Finished trajectory. Len=100, Returns=4488.708932. Progress:55279/200000
# Finished trajectory. Len=100, Returns=4183.476817. Progress:55379/200000
# Finished trajectory. Len=100, Returns=3780.288764. Progress:55479/200000
# Finished trajectory. Len=100, Returns=3356.860953. Progress:55579/200000
# Finished trajectory. Len=100, Returns=2046.593807. Progress:55679/200000
# Finished trajectory. Len=100, Returns=3190.944995. Progress:55779/200000
# Finished trajectory. Len=100, Returns=4056.145472. Progress:55879/200000
# Finished trajectory. Len=100, Returns=5342.071609. Progress:55979/200000
# Finished trajectory. Len=100, Returns=2558.916820. Progress:56079/200000
# Finished trajectory. Len=100, Returns=829.365632. Progress:56179/200000
# Finished trajectory. Len=100, Returns=5501.578049. Progress:56279/200000
# Finished trajectory. Len=100, Returns=3886.547404. Progress:56379/200000
# Finished trajectory. Len=100, Returns=5271.796894. Progress:56479/200000
# Finished trajectory. Len=100, Returns=3205.864943. Progress:56579/200000
# Finished trajectory. Len=100, Returns=5001.660843. Progress:56679/200000
# Finished trajectory. Len=100, Returns=5452.198648. Progress:56779/200000
# Finished trajectory. Len=100, Returns=846.502486. Progress:56879/200000
# Finished trajectory. Len=100, Returns=3507.130337. Progress:56979/200000
# Finished trajectory. Len=100, Returns=4801.758523. Progress:57079/200000
# Finished trajectory. Len=100, Returns=452.481040. Progress:57179/200000
# Finished trajectory. Len=100, Returns=5161.363055. Progress:57279/200000
# Finished trajectory. Len=100, Returns=31.045379. Progress:57379/200000
# Finished trajectory. Len=100, Returns=3144.666676. Progress:57479/200000
# Finished trajectory. Len=100, Returns=22.743907. Progress:57579/200000
# Finished trajectory. Len=100, Returns=4174.353377. Progress:57679/200000
# Finished trajectory. Len=100, Returns=4951.886218. Progress:57779/200000
# Finished trajectory. Len=100, Returns=4052.237928. Progress:57879/200000
# Finished trajectory. Len=100, Returns=2368.906877. Progress:57979/200000
# Finished trajectory. Len=100, Returns=4967.998479. Progress:58079/200000
# Finished trajectory. Len=100, Returns=5024.883271. Progress:58179/200000
# Finished trajectory. Len=100, Returns=4384.062413. Progress:58279/200000
# Finished trajectory. Len=100, Returns=559.135779. Progress:58379/200000
# Finished trajectory. Len=100, Returns=4307.797515. Progress:58479/200000
# Finished trajectory. Len=100, Returns=5090.254313. Progress:58579/200000
# Finished trajectory. Len=100, Returns=3776.268449. Progress:58679/200000
# Finished trajectory. Len=100, Returns=1049.170887. Progress:58779/200000
# Finished trajectory. Len=100, Returns=513.282613. Progress:58879/200000
# Finished trajectory. Len=100, Returns=4989.079238. Progress:58979/200000
# Finished trajectory. Len=100, Returns=5211.175359. Progress:59079/200000
# Finished trajectory. Len=100, Returns=5333.016386. Progress:59179/200000
# Finished trajectory. Len=100, Returns=5039.992449. Progress:59279/200000
# Finished trajectory. Len=100, Returns=5340.784882. Progress:59379/200000
# Finished trajectory. Len=100, Returns=3594.353120. Progress:59479/200000
# Finished trajectory. Len=100, Returns=4839.910160. Progress:59579/200000
# Finished trajectory. Len=100, Returns=888.582705. Progress:59679/200000
# Finished trajectory. Len=100, Returns=116.723739. Progress:59779/200000
# Finished trajectory. Len=100, Returns=5028.032348. Progress:59879/200000
# Finished trajectory. Len=100, Returns=5221.924199. Progress:59979/200000
# Finished trajectory. Len=100, Returns=4012.043049. Progress:60079/200000
# Finished trajectory. Len=100, Returns=4041.777836. Progress:60179/200000
# Finished trajectory. Len=100, Returns=1291.248536. Progress:60279/200000
# Finished trajectory. Len=100, Returns=2340.037769. Progress:60379/200000
# Finished trajectory. Len=100, Returns=4370.556695. Progress:60479/200000
# Finished trajectory. Len=100, Returns=425.106929. Progress:60579/200000
# Finished trajectory. Len=100, Returns=1028.202342. Progress:60679/200000
# Finished trajectory. Len=100, Returns=3695.624988. Progress:60779/200000
# Finished trajectory. Len=100, Returns=14.105741. Progress:60879/200000
# Finished trajectory. Len=100, Returns=4271.568423. Progress:60979/200000
# Finished trajectory. Len=100, Returns=3222.010850. Progress:61079/200000
# Finished trajectory. Len=100, Returns=2797.945638. Progress:61179/200000
# Finished trajectory. Len=100, Returns=386.846692. Progress:61279/200000
# Finished trajectory. Len=100, Returns=1076.623430. Progress:61379/200000
# Finished trajectory. Len=100, Returns=5451.795682. Progress:61479/200000
# Finished trajectory. Len=100, Returns=4173.792540. Progress:61579/200000
# Finished trajectory. Len=100, Returns=5049.230370. Progress:61679/200000
# Finished trajectory. Len=100, Returns=-43.687013. Progress:61779/200000
# Finished trajectory. Len=100, Returns=1865.652591. Progress:61879/200000
# Finished trajectory. Len=100, Returns=1708.818782. Progress:61979/200000
# Finished trajectory. Len=100, Returns=5157.987744. Progress:62079/200000
# Finished trajectory. Len=100, Returns=1374.599974. Progress:62179/200000
# Finished trajectory. Len=100, Returns=1743.048962. Progress:62279/200000
# Finished trajectory. Len=100, Returns=4838.273357. Progress:62379/200000
# Finished trajectory. Len=100, Returns=1948.624449. Progress:62479/200000
# Finished trajectory. Len=100, Returns=3391.251969. Progress:62579/200000
# Finished trajectory. Len=100, Returns=72.785197. Progress:62679/200000
# Finished trajectory. Len=100, Returns=3009.408041. Progress:62779/200000
# Finished trajectory. Len=100, Returns=-18.452180. Progress:62879/200000
# Finished trajectory. Len=100, Returns=5339.784489. Progress:62979/200000
# Finished trajectory. Len=100, Returns=5209.788270. Progress:63079/200000
# Finished trajectory. Len=100, Returns=1269.631889. Progress:63179/200000
# Finished trajectory. Len=100, Returns=4931.569201. Progress:63279/200000
# Finished trajectory. Len=100, Returns=3747.886465. Progress:63379/200000
# Finished trajectory. Len=100, Returns=5332.583228. Progress:63479/200000
# Finished trajectory. Len=100, Returns=3583.833107. Progress:63579/200000
# Finished trajectory. Len=100, Returns=651.808373. Progress:63679/200000
# Finished trajectory. Len=100, Returns=3624.275048. Progress:63779/200000
# Finished trajectory. Len=100, Returns=25.972816. Progress:63879/200000
# Finished trajectory. Len=100, Returns=3743.783099. Progress:63979/200000
# Finished trajectory. Len=100, Returns=5452.610333. Progress:64079/200000
# Finished trajectory. Len=100, Returns=4517.258755. Progress:64179/200000
# Finished trajectory. Len=100, Returns=2558.751784. Progress:64279/200000
# Finished trajectory. Len=100, Returns=405.186554. Progress:64379/200000
# Finished trajectory. Len=100, Returns=4589.189035. Progress:64479/200000
# Finished trajectory. Len=100, Returns=3477.929346. Progress:64579/200000
# Finished trajectory. Len=100, Returns=-57.690379. Progress:64679/200000
# Finished trajectory. Len=100, Returns=1775.527949. Progress:64779/200000
# Finished trajectory. Len=100, Returns=5026.863886. Progress:64879/200000
# Finished trajectory. Len=100, Returns=600.445828. Progress:64979/200000
# Finished trajectory. Len=100, Returns=3628.410608. Progress:65079/200000
# Finished trajectory. Len=100, Returns=3929.922786. Progress:65179/200000
# Finished trajectory. Len=100, Returns=1419.162105. Progress:65279/200000
# Finished trajectory. Len=100, Returns=2573.506446. Progress:65379/200000
# Finished trajectory. Len=100, Returns=4078.554530. Progress:65479/200000
# Finished trajectory. Len=100, Returns=4074.945299. Progress:65579/200000
# Finished trajectory. Len=100, Returns=1075.851141. Progress:65679/200000
# Finished trajectory. Len=100, Returns=3625.475267. Progress:65779/200000
# Finished trajectory. Len=100, Returns=3718.148851. Progress:65879/200000
# Finished trajectory. Len=100, Returns=4738.227418. Progress:65979/200000
# Finished trajectory. Len=100, Returns=3.481467. Progress:66079/200000
# ...
# Finished trajectory. Len=100, Returns=471.255603. Progress:178368/200000
# Finished trajectory. Len=100, Returns=1184.425484. Progress:178468/200000
# Finished trajectory. Len=100, Returns=300.798676. Progress:178568/200000
# Finished trajectory. Len=100, Returns=3105.649192. Progress:178668/200000
# Finished trajectory. Len=100, Returns=28.663283. Progress:178768/200000
# Finished trajectory. Len=100, Returns=5280.708887. Progress:178868/200000
# Finished trajectory. Len=100, Returns=2411.890870. Progress:178968/200000
# Finished trajectory. Len=100, Returns=2934.234677. Progress:179068/200000
# Finished trajectory. Len=100, Returns=1473.412595. Progress:179168/200000
# Finished trajectory. Len=100, Returns=399.100860. Progress:179268/200000
# Finished trajectory. Len=100, Returns=4053.857112. Progress:179368/200000
# Finished trajectory. Len=100, Returns=3966.033386. Progress:179468/200000
# Finished trajectory. Len=100, Returns=1028.427939. Progress:179568/200000
# Finished trajectory. Len=100, Returns=5221.464088. Progress:179668/200000
# Finished trajectory. Len=100, Returns=2124.441081. Progress:179768/200000
# Finished trajectory. Len=100, Returns=5392.723087. Progress:179868/200000
# Finished trajectory. Len=100, Returns=34.511777. Progress:179968/200000
# Finished trajectory. Len=100, Returns=2927.384994. Progress:180068/200000
# Finished trajectory. Len=100, Returns=51.383207. Progress:180168/200000
# Finished trajectory. Len=100, Returns=3645.507023. Progress:180268/200000
# Finished trajectory. Len=100, Returns=5290.731506. Progress:180368/200000
# Finished trajectory. Len=100, Returns=1843.382646. Progress:180468/200000
# Finished trajectory. Len=100, Returns=60.441617. Progress:180568/200000
# Finished trajectory. Len=100, Returns=14.215464. Progress:180668/200000
# Finished trajectory. Len=100, Returns=2800.873523. Progress:180768/200000
# Finished trajectory. Len=100, Returns=2958.714084. Progress:180868/200000
# Finished trajectory. Len=100, Returns=5452.964432. Progress:180968/200000
# Finished trajectory. Len=100, Returns=5149.969575. Progress:181068/200000
# Finished trajectory. Len=100, Returns=5451.775001. Progress:181168/200000
# Finished trajectory. Len=100, Returns=4465.225502. Progress:181268/200000
# Finished trajectory. Len=100, Returns=3406.667222. Progress:181368/200000
# Finished trajectory. Len=100, Returns=410.308683. Progress:181468/200000
# Finished trajectory. Len=100, Returns=4224.084408. Progress:181568/200000
# Finished trajectory. Len=100, Returns=2690.130675. Progress:181668/200000
# Finished trajectory. Len=100, Returns=5332.135817. Progress:181768/200000
# Finished trajectory. Len=100, Returns=4927.688387. Progress:181868/200000
# Finished trajectory. Len=100, Returns=5118.937622. Progress:181968/200000
# Finished trajectory. Len=100, Returns=4068.147862. Progress:182068/200000
# Finished trajectory. Len=100, Returns=5272.282569. Progress:182168/200000
# Finished trajectory. Len=100, Returns=5107.561795. Progress:182268/200000
# Finished trajectory. Len=100, Returns=2791.468969. Progress:182368/200000
# Finished trajectory. Len=100, Returns=454.308655. Progress:182468/200000
# Finished trajectory. Len=100, Returns=5511.822485. Progress:182568/200000
# Finished trajectory. Len=100, Returns=3717.833045. Progress:182668/200000
# Finished trajectory. Len=100, Returns=-56.338879. Progress:182768/200000
# Finished trajectory. Len=100, Returns=1143.585169. Progress:182868/200000
# Finished trajectory. Len=100, Returns=4591.959734. Progress:182968/200000
# Finished trajectory. Len=100, Returns=329.794171. Progress:183068/200000
# Finished trajectory. Len=100, Returns=5088.958399. Progress:183168/200000
# Finished trajectory. Len=100, Returns=5025.881787. Progress:183268/200000
# Finished trajectory. Len=100, Returns=2787.206120. Progress:183368/200000
# Finished trajectory. Len=100, Returns=4164.118293. Progress:183468/200000
# Finished trajectory. Len=100, Returns=5342.598556. Progress:183568/200000
# Finished trajectory. Len=100, Returns=4123.388472. Progress:183668/200000
# Finished trajectory. Len=100, Returns=5169.718893. Progress:183768/200000
# Finished trajectory. Len=100, Returns=5392.390393. Progress:183868/200000
# Finished trajectory. Len=100, Returns=1349.432058. Progress:183968/200000
# Finished trajectory. Len=100, Returns=3236.988655. Progress:184068/200000
# Finished trajectory. Len=100, Returns=5078.271879. Progress:184168/200000
# Finished trajectory. Len=100, Returns=5059.560895. Progress:184268/200000
# Finished trajectory. Len=100, Returns=5340.442239. Progress:184368/200000
# Finished trajectory. Len=100, Returns=1659.680962. Progress:184468/200000
# Finished trajectory. Len=100, Returns=5039.222345. Progress:184568/200000
# Finished trajectory. Len=100, Returns=4506.558370. Progress:184668/200000
# Finished trajectory. Len=100, Returns=5281.561966. Progress:184768/200000
# Finished trajectory. Len=100, Returns=5332.346943. Progress:184868/200000
# Finished trajectory. Len=100, Returns=3696.034196. Progress:184968/200000
# Finished trajectory. Len=100, Returns=2255.342324. Progress:185068/200000
# Finished trajectory. Len=100, Returns=3485.261623. Progress:185168/200000
# Finished trajectory. Len=100, Returns=1495.033869. Progress:185268/200000
# Finished trajectory. Len=100, Returns=934.046570. Progress:185368/200000
# Finished trajectory. Len=100, Returns=3229.881628. Progress:185468/200000
# Finished trajectory. Len=100, Returns=5401.238227. Progress:185568/200000
# Finished trajectory. Len=100, Returns=2085.007916. Progress:185668/200000
# Finished trajectory. Len=100, Returns=-25.445266. Progress:185768/200000
# Finished trajectory. Len=100, Returns=2831.279387. Progress:185868/200000
# Finished trajectory. Len=100, Returns=821.888283. Progress:185968/200000
# Finished trajectory. Len=100, Returns=4840.624005. Progress:186068/200000
# Finished trajectory. Len=100, Returns=4291.470757. Progress:186168/200000
# Finished trajectory. Len=100, Returns=2945.307826. Progress:186268/200000
# Finished trajectory. Len=100, Returns=4132.914972. Progress:186368/200000
# Finished trajectory. Len=100, Returns=189.004859. Progress:186468/200000
# Finished trajectory. Len=100, Returns=-62.580312. Progress:186568/200000
# Finished trajectory. Len=100, Returns=5230.571957. Progress:186668/200000
# Finished trajectory. Len=100, Returns=1383.318724. Progress:186768/200000
# Finished trajectory. Len=100, Returns=554.585383. Progress:186868/200000
# Finished trajectory. Len=100, Returns=3088.097882. Progress:186968/200000
# Finished trajectory. Len=100, Returns=5218.947940. Progress:187068/200000
# Finished trajectory. Len=100, Returns=102.441227. Progress:187168/200000
# Finished trajectory. Len=100, Returns=5200.688653. Progress:187268/200000
# Finished trajectory. Len=100, Returns=4053.187620. Progress:187368/200000
# Finished trajectory. Len=100, Returns=4393.265541. Progress:187468/200000
# Finished trajectory. Len=100, Returns=4683.970610. Progress:187568/200000
# Finished trajectory. Len=100, Returns=4988.013803. Progress:187668/200000
# Finished trajectory. Len=100, Returns=3958.804697. Progress:187768/200000
# Finished trajectory. Len=100, Returns=4903.289759. Progress:187868/200000
# Finished trajectory. Len=100, Returns=2014.118025. Progress:187968/200000
# Finished trajectory. Len=100, Returns=-17.929270. Progress:188068/200000
# Finished trajectory. Len=100, Returns=46.360375. Progress:188168/200000
# Finished trajectory. Len=100, Returns=4766.161505. Progress:188268/200000
# Finished trajectory. Len=100, Returns=246.691447. Progress:188368/200000
# Finished trajectory. Len=100, Returns=401.617625. Progress:188468/200000
# Finished trajectory. Len=100, Returns=4467.220263. Progress:188568/200000
# Finished trajectory. Len=100, Returns=4148.813220. Progress:188668/200000
# Finished trajectory. Len=100, Returns=4830.860696. Progress:188768/200000
# Finished trajectory. Len=100, Returns=5393.358719. Progress:188868/200000
# Finished trajectory. Len=100, Returns=2838.948874. Progress:188968/200000
# Finished trajectory. Len=100, Returns=5168.127191. Progress:189068/200000
# Finished trajectory. Len=100, Returns=4529.526917. Progress:189168/200000
# Finished trajectory. Len=100, Returns=239.458486. Progress:189268/200000
# Finished trajectory. Len=100, Returns=-8.974627. Progress:189368/200000
# Finished trajectory. Len=100, Returns=5341.643983. Progress:189468/200000
# Finished trajectory. Len=100, Returns=2484.958088. Progress:189568/200000
# Finished trajectory. Len=100, Returns=4504.116303. Progress:189668/200000
# Finished trajectory. Len=100, Returns=3687.017255. Progress:189768/200000
# Finished trajectory. Len=100, Returns=23.923408. Progress:189868/200000
# Finished trajectory. Len=100, Returns=5211.940824. Progress:189968/200000
# Finished trajectory. Len=100, Returns=5452.214623. Progress:190068/200000
# Finished trajectory. Len=100, Returns=863.063924. Progress:190168/200000
# Finished trajectory. Len=100, Returns=3703.469128. Progress:190268/200000
# Finished trajectory. Len=100, Returns=3252.117351. Progress:190368/200000
# Finished trajectory. Len=100, Returns=342.623538. Progress:190468/200000
# Finished trajectory. Len=100, Returns=34.443952. Progress:190568/200000
# Finished trajectory. Len=100, Returns=1789.577498. Progress:190668/200000
# Finished trajectory. Len=100, Returns=3854.157702. Progress:190768/200000
# Finished trajectory. Len=100, Returns=209.567048. Progress:190868/200000
# Finished trajectory. Len=100, Returns=26.777560. Progress:190968/200000
# Finished trajectory. Len=100, Returns=6.420716. Progress:191068/200000
# Finished trajectory. Len=100, Returns=5200.156028. Progress:191168/200000
# Finished trajectory. Len=100, Returns=-42.238313. Progress:191268/200000
# Finished trajectory. Len=100, Returns=3223.506433. Progress:191368/200000
# Finished trajectory. Len=100, Returns=2161.829061. Progress:191468/200000
# Finished trajectory. Len=100, Returns=5018.894424. Progress:191568/200000
# Finished trajectory. Len=100, Returns=5026.735860. Progress:191668/200000
# Finished trajectory. Len=100, Returns=3914.293265. Progress:191768/200000
# Finished trajectory. Len=100, Returns=1566.207411. Progress:191868/200000
# Finished trajectory. Len=100, Returns=5342.830254. Progress:191968/200000
# Finished trajectory. Len=100, Returns=2363.325813. Progress:192068/200000
# Finished trajectory. Len=100, Returns=582.892199. Progress:192168/200000
# Finished trajectory. Len=100, Returns=4681.876005. Progress:192268/200000
# Finished trajectory. Len=100, Returns=3586.226590. Progress:192368/200000
# Finished trajectory. Len=100, Returns=3387.468759. Progress:192468/200000
# Finished trajectory. Len=100, Returns=3334.500592. Progress:192568/200000
# Finished trajectory. Len=100, Returns=3695.019848. Progress:192668/200000
# Finished trajectory. Len=100, Returns=3286.783989. Progress:192768/200000
# Finished trajectory. Len=100, Returns=5271.519868. Progress:192868/200000
# Finished trajectory. Len=100, Returns=3687.790313. Progress:192968/200000
# Finished trajectory. Len=100, Returns=2433.969928. Progress:193068/200000
# Finished trajectory. Len=100, Returns=16.674273. Progress:193168/200000
# Finished trajectory. Len=100, Returns=4828.384378. Progress:193268/200000
# Finished trajectory. Len=100, Returns=3525.305193. Progress:193368/200000
# Finished trajectory. Len=100, Returns=3891.475165. Progress:193468/200000
# Finished trajectory. Len=100, Returns=4757.234613. Progress:193568/200000
# Finished trajectory. Len=100, Returns=4778.924143. Progress:193668/200000
# Finished trajectory. Len=100, Returns=5271.249910. Progress:193768/200000
# Finished trajectory. Len=100, Returns=3200.121895. Progress:193868/200000
# Finished trajectory. Len=100, Returns=4124.881306. Progress:193968/200000
# Finished trajectory. Len=100, Returns=2496.386680. Progress:194068/200000
# Finished trajectory. Len=100, Returns=1834.746630. Progress:194168/200000
# Finished trajectory. Len=100, Returns=26.028582. Progress:194268/200000
# Finished trajectory. Len=100, Returns=4718.084692. Progress:194368/200000
# Finished trajectory. Len=100, Returns=5211.923903. Progress:194468/200000
# Finished trajectory. Len=100, Returns=219.288656. Progress:194568/200000
# Finished trajectory. Len=100, Returns=2932.593268. Progress:194668/200000
# Finished trajectory. Len=100, Returns=2058.834638. Progress:194768/200000
# Finished trajectory. Len=100, Returns=4576.825737. Progress:194868/200000
# Finished trajectory. Len=100, Returns=4633.904568. Progress:194968/200000
# Finished trajectory. Len=100, Returns=5219.983954. Progress:195068/200000
# Finished trajectory. Len=100, Returns=3848.435836. Progress:195168/200000
# Finished trajectory. Len=100, Returns=246.284912. Progress:195268/200000
# Finished trajectory. Len=100, Returns=3606.544652. Progress:195368/200000
# Finished trajectory. Len=100, Returns=5400.747021. Progress:195468/200000
# Finished trajectory. Len=100, Returns=936.641082. Progress:195568/200000
# Finished trajectory. Len=100, Returns=2420.402671. Progress:195668/200000
# Finished trajectory. Len=100, Returns=2032.686711. Progress:195768/200000
# Finished trajectory. Len=100, Returns=29.435386. Progress:195868/200000
# Finished trajectory. Len=100, Returns=3473.846206. Progress:195968/200000
# Finished trajectory. Len=100, Returns=8.616896. Progress:196068/200000
# Finished trajectory. Len=100, Returns=3868.438431. Progress:196168/200000
# Finished trajectory. Len=100, Returns=1164.236650. Progress:196268/200000
# Finished trajectory. Len=100, Returns=5229.502541. Progress:196368/200000
# Finished trajectory. Len=100, Returns=3694.478363. Progress:196468/200000
# Finished trajectory. Len=100, Returns=2623.880726. Progress:196568/200000
# Finished trajectory. Len=100, Returns=-62.824265. Progress:196668/200000
# Finished trajectory. Len=100, Returns=4937.052075. Progress:196768/200000
# Finished trajectory. Len=100, Returns=4962.901478. Progress:196868/200000
# Finished trajectory. Len=100, Returns=1819.274010. Progress:196968/200000
# Finished trajectory. Len=100, Returns=1121.969976. Progress:197068/200000
# Finished trajectory. Len=100, Returns=6.297041. Progress:197168/200000
# Finished trajectory. Len=100, Returns=4028.893441. Progress:197268/200000
# Finished trajectory. Len=100, Returns=1841.704005. Progress:197368/200000
# Finished trajectory. Len=100, Returns=5290.142877. Progress:197468/200000
# Finished trajectory. Len=100, Returns=4383.497755. Progress:197568/200000
# Finished trajectory. Len=100, Returns=2738.867392. Progress:197668/200000
# Finished trajectory. Len=100, Returns=2913.113788. Progress:197768/200000
# Finished trajectory. Len=100, Returns=2371.386902. Progress:197868/200000
# Finished trajectory. Len=100, Returns=2752.429391. Progress:197968/200000
# Finished trajectory. Len=100, Returns=3157.352987. Progress:198068/200000
# Finished trajectory. Len=100, Returns=4136.941672. Progress:198168/200000
# Finished trajectory. Len=100, Returns=631.734970. Progress:198268/200000
# Finished trajectory. Len=100, Returns=48.179617. Progress:198368/200000
# Finished trajectory. Len=100, Returns=1013.772445. Progress:198468/200000
# Finished trajectory. Len=100, Returns=4102.667158. Progress:198568/200000
# Finished trajectory. Len=100, Returns=4829.017031. Progress:198668/200000
# Finished trajectory. Len=100, Returns=1006.866369. Progress:198768/200000
# Finished trajectory. Len=100, Returns=254.932462. Progress:198868/200000
# Finished trajectory. Len=100, Returns=5210.494210. Progress:198968/200000
# Finished trajectory. Len=100, Returns=1724.319554. Progress:199068/200000
# Finished trajectory. Len=100, Returns=543.709030. Progress:199168/200000
# Finished trajectory. Len=100, Returns=781.232355. Progress:199268/200000
# Finished trajectory. Len=100, Returns=4530.126194. Progress:199368/200000
# Finished trajectory. Len=100, Returns=4767.446386. Progress:199468/200000
# Finished trajectory. Len=100, Returns=709.623778. Progress:199568/200000
# Finished trajectory. Len=100, Returns=4407.055390. Progress:199668/200000
# Finished trajectory. Len=100, Returns=5075.444651. Progress:199768/200000
# Finished trajectory. Len=100, Returns=5086.620547. Progress:199868/200000
# Finished trajectory. Len=100, Returns=3774.045613. Progress:199968/200000

# %%
res = {}
for k in datasets[0].keys():
    res[k] = np.concatenate([dt[k] for dt in datasets])

# %%
res["observations"].shape
# Out:
# (1000000, 45)

# %%
save_data_to_h5_file(
    res, 
    str(PROJECT_ROOT_DIR / "rollout" / "data" / "iter_1" / (ENV_NAME + ("_best_sample" if deterministic_sample else "") + ".hdf5"))
)

# %%
from load_data import load_data
dataset = load_data(str(PROJECT_ROOT_DIR / "rollout" / "data" / "iter_1" / "pen-human-v1.hdf5"))
dataset
# Out:
# load datafile: 100%|██████████| 9/9 [00:04<00:00,  2.10it/s]
# {'actions': array([[-1.1054758 ,  0.13096562,  1.0931482 , ...,  0.79916024,
#           0.9697671 ,  0.81118095],
#         [-1.1475093 ,  0.10892096,  1.0735291 , ...,  0.86924833,
#           0.96660906,  0.8229687 ],
#         [-1.1701081 ,  0.07452677,  1.0579853 , ...,  0.9646203 ,
#           0.9837736 ,  0.765536  ],
#         ...,
#         [ 0.02724263, -0.72248864,  0.13412645, ...,  0.6933089 ,
#          -0.9144265 , -1.0692381 ],
#         [ 0.12028527, -0.78407896, -0.06322058, ...,  0.8675778 ,
#          -0.9193287 , -1.1127439 ],
#         [ 0.15655415, -0.79959774, -0.12202199, ...,  0.9007965 ,
#          -0.9298039 , -1.1037769 ]], dtype=float32),
#  'infos/action_log_probs': array([32.407917, 35.826454, 38.553032, ..., 35.43653 , 36.9997  ,
#         38.57376 ], dtype=float32),
#  'infos/qpos': array([[ 0.        ,  0.        ,  0.        , ...,  0.        ,
#           0.        ,  0.        ],
#         [-0.01715021, -0.00545185,  0.02351521, ...,  0.        ,
#           0.        , -0.        ],
#         [-0.05623769, -0.01617908,  0.07288487, ...,  0.        ,
#           0.        , -0.        ],
#         ...,
#         [ 0.07908836, -0.6719676 ,  0.17323752, ...,  1.3189257 ,
#          -0.87565404, -0.43972543],
#         [ 0.04613768, -0.6737473 ,  0.15481   , ...,  1.3211188 ,
#          -0.87514657, -0.43300134],
#         [ 0.01234669, -0.6751045 ,  0.1323244 , ...,  1.3050638 ,
#          -0.8547195 , -0.4312683 ]], dtype=float32),
#  'infos/qvel': array([[ 0.0000000e+00,  0.0000000e+00,  0.0000000e+00, ...,
#           0.0000000e+00,  0.0000000e+00,  0.0000000e+00],
#         [-2.7316754e+00, -8.1409550e-01,  3.6547062e+00, ...,
#           4.2038954e-45,  0.0000000e+00,  0.0000000e+00],
#         [-4.5900555e+00, -1.1735386e+00,  5.5994844e+00, ...,
#           5.6051939e-45,  0.0000000e+00, -0.0000000e+00],
#         ...,
#         [-2.9942048e+00, -4.4555280e-01, -1.7562369e+00, ...,
#           1.0935769e+00, -7.7759480e-01,  7.2430569e-01],
#         [-3.4039776e+00, -5.5920854e-02, -1.8720306e+00, ...,
#          -8.3931059e-01,  1.1059779e+00,  4.2245203e-01],
#         [-3.3382545e+00, -1.5131648e-01, -2.4380894e+00, ...,
#          -1.9190177e+00,  2.4133873e+00,  1.9629595e-01]], dtype=float32),
#  'next_observations': array([[-0.01715021, -0.00545185,  0.02351521, ...,  0.2741823 ,
#           0.49741608, -0.47435248],
#         [-0.05623769, -0.01617908,  0.07288487, ...,  0.2741823 ,
#           0.49741608, -0.47435248],
#         [-0.10961051, -0.02902208,  0.13404864, ...,  0.2741823 ,
#           0.49741608, -0.47435248],
#         ...,
#         [ 0.04613768, -0.6737473 ,  0.15481   , ..., -0.2665171 ,
#           0.02454414,  0.13177757],
#         [ 0.01234669, -0.6751045 ,  0.1323244 , ..., -0.254393  ,
#           0.01365125,  0.12028052],
#         [-0.01938643, -0.6769238 ,  0.10541707, ..., -0.23659635,
#          -0.00098598,  0.10361037]], dtype=float32),
#  'observations': array([[ 0.        ,  0.        ,  0.        , ...,  0.2741823 ,
#           0.49741608, -0.47435248],
#         [-0.01715021, -0.00545185,  0.02351521, ...,  0.2741823 ,
#           0.49741608, -0.47435248],
#         [-0.05623769, -0.01617908,  0.07288487, ...,  0.2741823 ,
#           0.49741608, -0.47435248],
#         ...,
#         [ 0.07908836, -0.6719676 ,  0.17323752, ..., -0.2621349 ,
#           0.02308304,  0.12969346],
#         [ 0.04613768, -0.6737473 ,  0.15481   , ..., -0.2665171 ,
#           0.02454414,  0.13177757],
#         [ 0.01234669, -0.6751045 ,  0.1323244 , ..., -0.254393  ,
#           0.01365125,  0.12028052]], dtype=float32),
#  'rewards': array([ 0.72580546,  0.72444034,  0.72210014, ..., 60.904392  ,
#         60.910427  , 60.91734   ], dtype=float32),
#  'terminals': array([False, False, False, ..., False, False, False]),
#  'timeouts': array([False, False, False, ..., False, False, False])}

# %%
dataset["actions"].shape
# Out:
# (1000000, 24)
